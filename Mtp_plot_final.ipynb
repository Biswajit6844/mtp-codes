# %%
import matplotlib.pyplot as plt
episodes = list(range(100))
x_coordinates = [
    -28, 103, 101, 100, 94, 101, 103, 102, 96, 98, 97,94, 100, 98, 99, 103, 99, 95, 98, 102, 97, 98, 100, 99,
    101, 102, 94, 96, 101, 94, 101, 97, 94, 103, 98, 97, 94, 98, 101,102, 101, 98, 96, 95, 101, 100, 100, 96, 98, 101
    , 100, 103, 97, 102, 99,103, 98, 94, 102, 95, 99, 98, 101, 95, 101, 102, 94, 97, 95, 102, 100,
    96, 94, 98, 95, 98, 102, 96, 94, 94, 96, 102, 97, 101, 94, 97, 101,
    97, 100, 97, 94, 97, 101, 97, 96, 98, 101, 97, 98
]
y_coordinates = [
    -5, 47, 44, 52, 44, 53, 47, 53, 51, 48, 50,49, 51, 45, 47, 48, 47, 49, 50, 49, 47, 52, 47, 49,
    51, 50, 44, 46, 48, 53, 44, 53, 44, 49, 44, 49, 53, 51, 47,47, 47, 48, 53, 47, 52, 51, 52, 52
    , 46, 50, 45, 48, 49, 51, 46,46, 46, 53, 47, 46, 46, 53, 51, 49, 50, 52, 46, 48, 49, 49, 50,
    45, 45, 49, 49, 44, 47, 50, 47, 52, 47, 46, 49, 51, 48, 49, 51,
    49, 44, 51, 44, 51, 50, 49, 47, 48, 46, 44, 47



]
# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(x_coordinates, y_coordinates, color='blue', label='UAV Positions')
plt.title('UAV X and Y Coordinates')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
episodes = list(range(100))
x_coordinates = [
    -28, 103, 101, 100, 94, 101, 103, 102, 96, 98, 97, 94, 100, 98, 99, 103, 99, 95, 98, 102, 97, 98, 100, 99,
    101, 102, 94, 96, 101, 94, 101, 97, 94, 103, 98, 97, 94, 98, 101, 102, 101, 98, 96, 95, 101, 100, 100, 96, 98, 101,
    100, 103, 97, 102, 99, 103, 98, 94, 102, 95, 99, 98, 101, 95, 101, 102, 94, 97, 95, 102, 100, 96, 94, 98, 95, 98, 102, 96, 94, 94, 96, 102, 97, 101, 94, 97, 101,
    97, 100, 97, 94, 97, 101, 97, 96, 98, 101, 97, 98
]
y_coordinates = [
    -5, 47, 44, 52, 44, 53, 47, 53, 51, 48, 50, 49, 51, 45, 47, 48, 47, 49, 50, 49, 47, 52, 47, 49,
    51, 50, 44, 46, 48, 53, 44, 53, 44, 49, 44, 49, 53, 51, 47, 47, 47, 48, 53, 47, 52, 51, 52, 52, 46, 50, 45, 48, 49, 51, 46, 46, 46, 53, 47, 46, 46, 53, 51, 49, 50, 52, 46, 48, 49, 49, 50, 45, 45, 49, 49, 44, 47, 50, 47, 52, 47, 46, 49, 51, 48, 49, 51, 49, 44, 51, 44, 51, 50, 49, 47, 48, 46, 44, 47
]


plt.figure(figsize=(10, 4))
plt.scatter(x_coordinates, y_coordinates, color='blue', s=50)
plt.scatter([x_coordinates[-1]], [y_coordinates[-1]], color='red', s=100, label='Final Position')
plt.title('UAV X and Y Coordinates')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.xlim(90, 110)
plt.ylim(40, 60)
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
episodes = list(range(100))
x_coordinates = [
    112, 99, 98, 96, 104, 101, 105, 100, 101, 100, 101, 96, 102, 99, 97,
    101, 104, 99, 98, 102, 97, 102, 99, 99, 103, 98, 96, 97,
    102, 99, 99, 97, 103, 105, 104, 104, 96, 101, 98, 101, 101,
    100, 105, 104, 103, 104, 102, 96, 101, 98, 101, 104, 97, 95,
    96, 100, 104, 103, 97, 102, 101, 102, 100, 98, 95, 99, 96,
101, 96, 97, 104, 105, 97, 101, 103, 99, 97, 95, 100, 99, 98,
   102, 94, 99, 100, 103, 97, 94, 99, 101, 94, 100, 95, 99,
     96, 102, 98, 94, 95, 94
]
y_coordinates = [
    -56, 48, 50, 48, 47, 46, 49, 45, 47, 50, 46, 53, 47, 48, 44,
    47, 48, 51, 50, 44, 48, 53, 53, 44, 45, 47, 49, 47,
49, 53, 53, 53, 50, 52, 53, 49, 53, 51, 46, 53, 51,
    52, 50, 44, 48, 51, 52, 52, 48, 44, 45, 48, 45, 52,
47, 49, 50, 52, 47, 47, 53, 51, 45, 53, 45, 49, 44,
  46, 46, 51, 51, 47, 47, 49, 48, 51, 50, 47, 52, 49, 53,
    50, 47, 50, 50, 47, 52, 52, 44, 50, 48, 45, 49, 45,
52, 48, 44, 52, 49, 44

]

# Plotting with adjustments and marking the final position
plt.figure(figsize=(10, 4))  # Increase figure size for better visibility
plt.scatter(x_coordinates, y_coordinates, color='blue', s=50)  # Blue dots for all positions
plt.scatter([x_coordinates[-1]], [y_coordinates[-1]], color='red', s=100, label='Final Position')  # Red dot for the final position
plt.title('UAV X and Y Coordinates')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.xlim(90, 110)  # Adjusting the x-axis limits to focus on the main cluster
plt.ylim(40, 60)   # Adjusting the y-axis limits to focus on the main cluster
plt.grid(True)
plt.legend()  # Adding a legend to identify the final position
plt.show()

# %%
import numpy as np
import pandas as pd
from scipy.optimize import differential_evolution
N = 800
K = 3
T = 60
zeta = 0.8
RIS_elements = np.exp(1j * 2 * np.pi * np.random.rand(80, 10, K))
sigma2 = 10**(-8)
Pk = np.array([0.1, 0.2, 0.3])
H1 = np.random.rand(80, 10)
h2k = np.random.rand(80, 10, K)
LBS = np.array([-200, 0, 0])
Qj = np.array([100, 50, 100])
obstacle_position = np.array([80, 40, 0])
def fitness_function(x, H1, h2k, Pk, sigma2, zeta):
    x = x.reshape((80, 10, K))
    Phi = np.exp(1j * x)
    H_eff = H1[:, :, np.newaxis] * h2k * Phi
    snr = (np.abs(H_eff.sum(axis=0))**2 / sigma2) * Pk
    sum_rate = np.sum(np.log2(1 + snr))
    power_consumption = np.sum(Pk) / zeta
    energy_efficiency = sum_rate / power_consumption
    return -energy_efficiency
# Genetic Algorithm optimization
bounds = [(0, 2 * np.pi) for _ in range(80 * 10 * K)]  # (0, 2*pi) bounds for each phase shift element
result = differential_evolution(
    fitness_function, bounds, args=(H1, h2k, Pk, sigma2, zeta),
    strategy='best1bin', maxiter=30, popsize=20, tol=0.01, mutation=(0.5, 1), recombination=0.7
)
optimized_phases = result.x.reshape((80, 10, K))
optimized_RIS_elements = np.exp(1j * optimized_phases)
H_eff_optimized = H1[:, :, np.newaxis] * h2k * optimized_RIS_elements
snr_optimized = (np.abs(H_eff_optimized.sum(axis=0))**2 / sigma2) * Pk
sum_rate_optimized = np.sum(np.log2(1 + snr_optimized))
power_consumption_optimized = np.sum(Pk) / zeta
energy_efficiency_optimized = sum_rate_optimized / power_consumption_optimized
# Out:
# Optimized Energy Efficiency: 1161.7001822304971

# %%
import matplotlib.pyplot as plt

# Correctly sized data lists
episodes = list(range(100))  # Episodes from 0 to 99
x_coordinates = [
   -3, 97, 97, 97, 103, 95, 100, 97, 97, 103, 95, 102, 96, 103,
   101, 94, 102, 99, 101, 98, 103, 98, 103, 100, 101, 96, 98,
103, 101, 95, 99, 94, 101, 102, 100, 102, 99, 94, 96, 94, 94, 99, 99,
95, 100, 97, 101, 95, 94, 98, 97, 96, 99, 101, 101, 94, 97, 103, 95,
 102, 97, 97, 97, 103, 95, 101, 103, 98, 103, 95, 94, 100, 103, 95,
   94, 94, 96, 98, 95, 100, 100, 97, 96, 102, 98, 102, 105, 100, 101, 97,
103, 100, 97, 99, 98, 99, 102, 105, 101, 99
]
y_coordinates = [
    104, 47, 55, 46, 49, 55, 51, 50, 48, 49, 54, 51, 55, 52,
    51, 55, 53, 47, 51, 54, 53, 55, 51, 50, 47, 54, 49,
46, 47, 51, 47, 53, 53, 52, 52, 47, 55, 46, 53, 46, 53, 50, 50,
53, 53, 46, 50, 47, 47, 51, 53, 51, 50, 53, 50, 47, 46, 46, 47,
    47, 47, 50, 51, 50, 54, 49, 52, 49, 53, 52, 53, 46, 55, 55,
49, 48, 48, 55, 52, 51, 54, 47, 55, 49, 49, 53, 49, 54, 51, 54,
 53, 55, 47, 55, 49, 47, 55, 55, 46, 53
]

# Plotting with adjustments and marking the final position
plt.figure(figsize=(10, 4))  # Increase figure size for better visibility
plt.scatter(x_coordinates, y_coordinates, color='blue', s=50)  # Blue dots for all positions
plt.scatter([x_coordinates[-1]], [y_coordinates[-1]], color='red', s=100, label='Final Position')  # Red dot for the final position
plt.title('UAV X and Y Coordinates')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.xlim(90, 110)  # Adjusting the x-axis limits to focus on the main cluster
plt.ylim(40, 60)   # Adjusting the y-axis limits to focus on the main cluster
plt.grid(True)
plt.legend()  # Adding a legend to identify the final position
plt.show()

# %%
#Implement swipt+Phase  Shift+UAV  position using DDPG Algorithm  with NoMA  for  100  episodes.
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
import random
import collections
from tabulate import tabulate

class CommunicationEnvironment:
    def __init__(self, max_steps):

        self.sinr_history = []
        self.efficiency_history = []
        self.stability_check_window = 10


        self.current_step = 0
        self.max_steps = max_steps
        # Channel gains
        self.H1 = np.random.rand(1, 1)
        self.h2k = np.random.rand(800, 3)


        self.R = np.random.uniform(0, 30)
        self.alpha = np.random.uniform(2, 5)
        self.beta = np.random.uniform(0, 1)


        self.M = 1
        self.N = 800
        self.K = 3
        self.power_for_energy_harvesting = np.zeros(self.K)



        self.Phi = np.exp(1j * np.random.rand(self.N) * 2 * np.pi)
        self.wi = np.random.rand(self.M, self.K)
        self.x = np.random.rand(self.M, 1)
        self.sk = np.random.rand(self.K, 1)
        self.sigma = 10**(-8/10)
        self.gamma_k = np.random.rand(self.K)
        self.B = 1e6
        self.zeta = 1.2
        self.P_BS = 10**(39/10)
        self.P_k = np.random.rand(self.K) * 10**(30/10)
        self.P_UAV = 10**(30/10)
        self.P_UE = 10**(10/10)
        self.P_RIS = self.N * 10**(0.8/10)
        self.P_RISn = 10**(0.8/10)


        self.L_BS = np.array([-200, 0, 0])
        self.Q_j = np.array([100, 50, 100])
        self.user_positions = np.array([[75, 25, 0], [125, 25, 0], [100, 75, 0]])
        self.obstacle_position = np.array([80, 40, 0])




    def reset(self):

        self.H1 = np.random.rand(1, 1)
        self.h2k = np.random.rand(800, 3)


        self.Q_j = np.array([100, 50, 100])

        self.Phi = np.exp(1j * np.random.rand(self.N) * 2 * np.pi)
        self.wi = np.random.rand(self.M, self.K)
        self.x = np.random.rand(self.M, 1)
        self.sk = np.random.rand(self.K, 1)
        self.gamma_k = np.random.rand(self.K)


        state = self._get_state()
        return state

    def _get_state(self):

        state = np.concatenate((self.H1.flatten(), self.h2k.flatten(), self.Q_j, self.user_positions.flatten()))
        return state


    def step(self, action):


        self._apply_action(action)

        previous_energy_harvested = self.get_energy_harvested()
        self._update_environment()


        self.adjust_uav_position_for_optimal_energy_harvesting()

        self._noma_power_allocation()




        reward = self._calculate_reward()


        done = self._check_done()


        new_state = self._get_state()

        return new_state, reward, done


    def adjust_uav_position_for_optimal_energy_harvesting(self):

        best_position = self.Q_j[:2]
        best_energy = self.get_energy_harvested()
        best_h2k = np.copy(self.h2k)

        for _ in range(10):
            trial_position = self.Q_j[:2] + (np.random.rand(2) - 0.5) * 10
            trial_position = self._apply_position_constraints(trial_position)


            original_position = np.copy(self.Q_j)
            self.Q_j[:2] = trial_position


            self._update_environment()


            trial_energy = self.get_energy_harvested()


            if trial_energy > best_energy:
                best_position = trial_position
                best_energy = trial_energy
                best_h2k = np.copy(self.h2k)


            self.Q_j = original_position


        self.Q_j[:2] = best_position
        self.h2k = best_h2k
        self._update_environment()









    def _apply_action(self, action):
      uav_movement = action[:2]
      phase_shift_changes = action[2:]
      new_position = self.Q_j[:2] + uav_movement
      self.Q_j[:2] = self._apply_position_constraints(new_position)


      if len(phase_shift_changes) < len(self.Phi):
        phase_shift_changes = np.concatenate([phase_shift_changes, np.zeros(len(self.Phi) - len(phase_shift_changes))])
      elif len(phase_shift_changes) > len(self.Phi):
        phase_shift_changes = phase_shift_changes[:len(self.Phi)]


      phase_shift_changes = np.array(phase_shift_changes)


      current_angles = np.angle(self.Phi)


      new_angles = (current_angles + phase_shift_changes) % (2 * np.pi)


      self.Phi = np.abs(self.Phi) * np.exp(1j * new_angles)









    def _apply_position_constraints(self, position):

        max_x, max_y = 200, 200
        min_x, min_y = -200, -200
        constrained_x = np.clip(position[0], min_x, max_x)
        constrained_y = np.clip(position[1], min_y, max_y)
        return np.array([constrained_x, constrained_y])

    def _update_environment(self):

        distance_bs_ris = np.linalg.norm(self.L_BS - self.Q_j)
        self.H1 = self._calculate_path_loss(distance_bs_ris)


        for k in range(self.K):
            distance_ris_user = np.linalg.norm(self.user_positions[k][:2] - self.Q_j[:2])
            self.h2k[:, k] = self._calculate_path_loss(distance_ris_user) * self._apply_phase_shifts(self.Phi)

        self._update_swipt_signals()










    def _calculate_path_loss(self, distance):
      frequency = 2.4e9
      c = 3e8
      path_loss_0 = 20 * np.log10(4 * np.pi * frequency / c)

      path_loss = 20 * np.log10(distance) + path_loss_0
      path_loss_linear = 10 ** (-path_loss / 10)

      return path_loss_linear



    def _apply_phase_shifts(self, phi):

        return np.exp(1j * phi)

    def _update_swipt_signals(self):

        power_split_ratio = 0.5
        self.power_for_information = self.P_k * power_split_ratio
        self.power_for_energy_harvesting = self.P_k * (1 - power_split_ratio)


    def _calculate_reward(self):

        sinr_values = []
        sorted_indices = np.argsort(self.h2k.mean(axis=0))
        for k in sorted_indices:
            signal_power = np.abs(self.h2k[:, k])**2 * self.P_k[k]
            interference_power = np.sum([np.abs(self.h2k[:, i])**2 * self.P_k[i] for i in sorted_indices if i > k])
            noise_power = self.sigma  # Using noise variance as noise power
            sinr = signal_power / (interference_power + noise_power)
            sinr_values.append(sinr)


        energy_efficiency = self._calculate_energy_efficiency()


        reward_signal_quality = np.log(1 + np.mean(sinr_values))
        total_reward = reward_signal_quality + energy_efficiency
        return total_reward

    def _calculate_signal_quality(self):


        sinr_values = []

        for k in range(self.K):


            signal_power = np.abs(self.h2k[:, k])**2


            interference_power = 1


            noise_power = self.sigma


            sinr = signal_power / (interference_power + noise_power)
            sinr_values.append(sinr)


        average_sinr = np.mean(sinr_values)


        signal_quality_reward = np.log(1 + average_sinr)

        self.sinr_history.append(signal_quality_reward)


        return signal_quality_reward


    def _calculate_energy_efficiency(self):

        total_energy_harvested = np.sum(self.power_for_energy_harvesting)


        total_energy_used = np.sum(self.power_for_information)


        if total_energy_used > 0:
            energy_efficiency = total_energy_harvested / total_energy_used
        else:
            energy_efficiency = 0


        energy_efficiency_reward = energy_efficiency

        self.efficiency_history.append(energy_efficiency_reward)

        return energy_efficiency_reward

    def _check_done(self):

        self.current_step += 1
        if self.current_step >= self.max_steps:
            return True
        return False

    def _check_stability_or_convergence(self):

        sinr_threshold = 0.01
        efficiency_threshold = 0.01


        if len(self.sinr_history) >= self.stability_check_window:
            recent_sinr_changes = np.abs(np.diff(self.sinr_history[-self.stability_check_window:]))
            recent_efficiency_changes = np.abs(np.diff(self.efficiency_history[-self.stability_check_window:]))


            if np.all(recent_sinr_changes < sinr_threshold) and np.all(recent_efficiency_changes < efficiency_threshold):
                return True

        return False

    def get_energy_harvested(self):

        return np.sum(self.power_for_energy_harvesting)

    def get_transmit_power(self):

        return self.P_k

    def get_uav_position(self):

        return self.Q_j

    def get_phase_shifts(self):

        return np.angle(self.Phi)

    def _noma_power_allocation(self):

        sorted_indices = np.argsort(self.h2k.mean(axis=0))

        total_power = self.P_BS
        power_allocations = np.zeros(self.K)
        for idx in sorted_indices:

            power_allocations[idx] = total_power / (self.K - idx)
            total_power -= power_allocations[idx]
        self.P_k = power_allocations





class Actor(Model):

    def __init__(self, state_size, action_size, learning_rate=0.001):
        super(Actor, self).__init__()
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate


        self.dense1 = Dense(400, input_dim=self.state_size, activation='relu')
        self.dense2 = Dense(300, activation='relu')
        self.output_layer = Dense(self.action_size, activation='tanh')  # 'tanh' for bounded actions

        self.compile(optimizer=Adam(learning_rate=self.learning_rate))

    def call(self, state):
        x = self.dense1(state)
        x = self.dense2(x)
        action = self.output_layer(x)
        return action



class Critic(Model):

    def __init__(self, state_size, action_size, learning_rate=0.001):
        super(Critic, self).__init__()
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate


        self.state_input = Input(shape=(self.state_size,))
        self.state_h1 = Dense(400, activation='relu')(self.state_input)
        self.state_h2 = Dense(300, activation='relu')(self.state_h1)


        self.action_input = Input(shape=(self.action_size,))
        self.action_h1 = Dense(300, activation='relu')(self.action_input)


        merged = tf.keras.layers.Concatenate()([self.state_h2, self.action_h1])


        self.output_layer = Dense(1, activation='linear')(merged)

        self.model = Model(inputs=[self.state_input, self.action_input], outputs=self.output_layer)
        self.optimizer = Adam(learning_rate=self.learning_rate)
        self.model.compile(loss='mse', optimizer=self.optimizer)

    def call(self, inputs):
        return self.model(inputs)

class ReplayBuffer:
    def __init__(self, buffer_size):
        self.buffer_size = buffer_size
        self.buffer = collections.deque(maxlen=buffer_size)

    def add(self, state, action, reward, next_state, done):
        experience = (state, action, reward, next_state, done)
        self.buffer.append(experience)

    def sample(self, batch_size):
        batch = random.sample(self.buffer, min(len(self.buffer), batch_size))
        states, actions, rewards, next_states, dones = map(np.stack, zip(*batch))
        return states, actions, rewards, next_states, dones

class DDPGAgent:
    def __init__(self, state_size, action_size, actor_lr, critic_lr, buffer_size, batch_size, tau=0.001):
        self.state_size = state_size
        self.action_size = action_size
        self.buffer_size = buffer_size
        self.batch_size = batch_size
        self.tau = tau

        # Initialize actor and critic networks
        self.actor = Actor(state_size, action_size, actor_lr)
        self.critic = Critic(state_size, action_size, critic_lr)


        self.target_actor = Actor(state_size, action_size, actor_lr)
        self.target_critic = Critic(state_size, action_size, critic_lr)


        self.replay_buffer = ReplayBuffer(buffer_size)


        self.update_target_networks()

    def update_target_networks(self):

        self._soft_update(self.actor, self.target_actor)
        self._soft_update(self.critic, self.target_critic)

    def _soft_update(self, model, target_model):
        for target_param, param in zip(target_model.trainable_variables, model.trainable_variables):
            target_param.assign(self.tau * param + (1 - self.tau) * target_param)

    def learn(self):

        states, actions, rewards, next_states, dones = self.replay_buffer.sample(self.batch_size)


        target_actions = self.target_actor(states)
        target_critic_values = self.target_critic([next_states, target_actions])
        target_q_values = rewards + (1 - dones) * 0.99 * target_critic_values



        with tf.GradientTape() as tape:
            critic_values = self.critic([states, actions])
            critic_loss = tf.reduce_mean(tf.square(target_q_values - critic_values))
        critic_grad = tape.gradient(critic_loss, self.critic.trainable_variables)
        self.critic.optimizer.apply_gradients(zip(critic_grad, self.critic.trainable_variables))




        with tf.GradientTape() as tape:
            actions_pred = self.actor(states)
            critic_values_pred = self.critic([states, actions_pred])

            actor_loss = -tf.math.reduce_mean(critic_values_pred)
        actor_grad = tape.gradient(actor_loss, self.actor.trainable_variables)
        self.actor.optimizer.apply_gradients(zip(actor_grad, self.actor.trainable_variables))



    def act(self, states):

        actions = self.actor(states)

        clipped_actions = tf.clip_by_value(actions, -1, 1)
        return clipped_actions


    def update_target(self):

        actor_weights = self.actor.get_weights()
        target_actor_weights = self.target_actor.get_weights()
        for i in range(len(actor_weights)):
            target_actor_weights[i] = tau * actor_weights[i] + (1 - tau) * target_actor_weights[i]
        self.target_actor.set_weights(target_actor_weights)


        critic_weights = self.critic.get_weights()
        target_critic_weights = self.target_critic.get_weights()
        for i in range(len(critic_weights)):
            target_critic_weights[i] = tau * critic_weights[i] + (1 - tau) * target_critic_weights[i]
        self.target_critic.set_weights(target_critic_weights)




env = CommunicationEnvironment(max_steps=100)
state = env.reset()
state_size = len(state)
action_size = len(env.Phi)

tau = 0.001



agent = DDPGAgent(state_size, action_size, actor_lr=0.001, critic_lr=0.002, buffer_size=100000, batch_size=64, tau=tau)


agent = DDPGAgent(state_size, action_size, actor_lr=0.001, critic_lr=0.002, buffer_size=100000, batch_size=64, tau=tau)

energy_harvested_per_episode = []
transmit_powers = []
phase_shifts = []
uav_positions = []


for episode in range(100):
    state = env.reset()
    total_reward = 0
    done = False

    while not done:
        action = agent.act(np.array([state]))[0]  # Need to pass a batch of states
        next_state, reward, done = env.step(action)
        agent.replay_buffer.add(state, action, reward, next_state, done)
        agent.learn()
        state = next_state
        total_reward += reward

    agent.update_target_networks()
    print(f"Episode: {episode}, Total Reward: {total_reward}")


    energy_harvested_per_episode.append(env.get_energy_harvested())
    uav_positions.append(env.get_uav_position())
    if episode == 99:
      transmit_powers = env.get_transmit_power()
      phase_shifts = env.get_phase_shifts()

print("\nEnergy Harvested Per Episode:")
print(tabulate([[i, eh] for i, eh in enumerate(energy_harvested_per_episode)], headers=["Episode", "Energy Harvested"], tablefmt="grid"))



print("\nPhase Shifts:")
print(tabulate([[i, ps] for i, ps in enumerate(phase_shifts)], headers=["Element", "Phase Shift"], tablefmt="grid"))
print("\nTransmit Powers for Each User:")
print(tabulate([[f"User {i+1}", tp] for i, tp in enumerate(env.P_k)], headers=["User", "Transmit Power"], tablefmt="grid"))

print("\nUAV Positions:")
print(tabulate([[i] + list(pos) for i, pos in enumerate(uav_positions)], headers=["Episode", "X-Coordinate", "Y-Coordinate", "Z-Coordinate"], tablefmt="grid"))


max_energy_harvested = max(energy_harvested_per_episode)
energy_harvested_ratio = [eh / max_energy_harvested for eh in energy_harvested_per_episode]



transmit_powers_db = 10 * np.log10(transmit_powers)


print("\nTransmit Powers for Each User in dB (Last Episode):")
print(tabulate([[f"User {i+1}", tp_db] for i, tp_db in enumerate(transmit_powers_db)], headers=["User", "Transmit Power (dB)"], tablefmt="grid"))
# Out:
# <ipython-input-3-3cb666cc96c5>:217: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.h2k[:, k] = self._calculate_path_loss(distance_ris_user) * self._apply_phase_shifts(self.Phi)
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7e8990a436d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7e8990a436d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Episode: 0, Total Reward: 100.00000000291574
# Episode: 1, Total Reward: 1.000000000251395
# Episode: 2, Total Reward: 1.0000000002630747
# Episode: 3, Total Reward: 1.0000000003420304
# Episode: 4, Total Reward: 1.0000000003950131
# Episode: 5, Total Reward: 1.000000000246584
# Episode: 6, Total Reward: 1.0000000003327258
# Episode: 7, Total Reward: 1.0000000004357028
# Episode: 8, Total Reward: 1.0000000002879117
# Episode: 9, Total Reward: 1.0000000002802203
# Episode: 10, Total Reward: 1.0000000002652636
# Episode: 11, Total Reward: 1.0000000002891523
# Episode: 12, Total Reward: 1.0000000003499705
# Episode: 13, Total Reward: 1.0000000002975962
# Episode: 14, Total Reward: 1.000000000509571
# Episode: 15, Total Reward: 1.0000000003114935
# Episode: 16, Total Reward: 1.0000000002814449
# Episode: 17, Total Reward: 1.000000000269105
# Episode: 18, Total Reward: 1.0000000002833302
# Episode: 19, Total Reward: 1.00000000024927
# Episode: 20, Total Reward: 1.0000000002893454
# Episode: 21, Total Reward: 1.0000000002965235
# Episode: 22, Total Reward: 1.0000000004500742
# Episode: 23, Total Reward: 1.000000000222678
# Episode: 24, Total Reward: 1.0000000003911251
# Episode: 25, Total Reward: 1.0000000003233456
# Episode: 26, Total Reward: 1.000000000480907
# Episode: 27, Total Reward: 1.0000000002738563
# Episode: 28, Total Reward: 1.0000000004758582
# Episode: 29, Total Reward: 1.0000000002751785
# Episode: 30, Total Reward: 1.0000000005484246
# Episode: 31, Total Reward: 1.0000000002664495
# Episode: 32, Total Reward: 1.000000000373819
# Episode: 33, Total Reward: 1.000000000542159
# Episode: 34, Total Reward: 1.0000000005092469
# Episode: 35, Total Reward: 1.0000000006131575
# Episode: 36, Total Reward: 1.0000000006670757
# Episode: 37, Total Reward: 1.0000000003935292
# Episode: 38, Total Reward: 1.0000000002584424
# Episode: 39, Total Reward: 1.0000000004286083
# Episode: 40, Total Reward: 1.0000000004339868
# Episode: 41, Total Reward: 1.0000000002861285
# Episode: 42, Total Reward: 1.000000000388559
# Episode: 43, Total Reward: 1.0000000006130045
# Episode: 44, Total Reward: 1.0000000003392886
# Episode: 45, Total Reward: 1.0000000003042702
# Episode: 46, Total Reward: 1.0000000005122227
# Episode: 47, Total Reward: 1.000000000537085
# Episode: 48, Total Reward: 1.0000000002781082
# Episode: 49, Total Reward: 1.0000000006045204
# Episode: 50, Total Reward: 1.0000000003864105
# Episode: 51, Total Reward: 1.0000000003401348
# Episode: 52, Total Reward: 1.0000000002461413
# Episode: 53, Total Reward: 1.0000000005123424
# Episode: 54, Total Reward: 1.0000000006027736
# Episode: 55, Total Reward: 1.000000000330164
# Episode: 56, Total Reward: 1.000000000290376
# Episode: 57, Total Reward: 1.0000000004063274
# Episode: 58, Total Reward: 1.0000000004177927
# Episode: 59, Total Reward: 1.000000000442233
# Episode: 60, Total Reward: 1.0000000002983704
# Episode: 61, Total Reward: 1.000000000347283
# Episode: 62, Total Reward: 1.0000000003671632
# Episode: 63, Total Reward: 1.0000000003413636
# Episode: 64, Total Reward: 1.000000000285273
# Episode: 65, Total Reward: 1.0000000002624665
# Episode: 66, Total Reward: 1.0000000003789717
# Episode: 67, Total Reward: 1.0000000002879725
# Episode: 68, Total Reward: 1.0000000006357879
# Episode: 69, Total Reward: 1.000000000300988
# Episode: 70, Total Reward: 1.0000000006199465
# Episode: 71, Total Reward: 1.0000000005151986
# Episode: 72, Total Reward: 1.000000000348034
# Episode: 73, Total Reward: 1.0000000005129837
# Episode: 74, Total Reward: 1.0000000003048422
# Episode: 75, Total Reward: 1.000000000518952
# Episode: 76, Total Reward: 1.0000000003111886
# Episode: 77, Total Reward: 1.000000000433015
# Episode: 78, Total Reward: 1.0000000003284528
# Episode: 79, Total Reward: 1.000000000277886
# Episode: 80, Total Reward: 1.0000000006217438
# Episode: 81, Total Reward: 1.000000000367899
# Episode: 82, Total Reward: 1.0000000003240512
# Episode: 83, Total Reward: 1.0000000003504361
# Episode: 84, Total Reward: 1.000000000421203
# Episode: 85, Total Reward: 1.0000000002928586
# Episode: 86, Total Reward: 1.0000000003555805
# Episode: 87, Total Reward: 1.0000000002497322
# Episode: 88, Total Reward: 1.0000000003183758
# Episode: 89, Total Reward: 1.0000000004478307
# Episode: 90, Total Reward: 1.000000000273406
# Episode: 91, Total Reward: 1.0000000003970566
# Episode: 92, Total Reward: 1.0000000004404088
# Episode: 93, Total Reward: 1.0000000003568221
# Episode: 94, Total Reward: 1.0000000005522682
# Episode: 95, Total Reward: 1.0000000002770748
# Episode: 96, Total Reward: 1.0000000003253822
# Episode: 97, Total Reward: 1.0000000003897993
# Episode: 98, Total Reward: 1.0000000006037535
# Episode: 99, Total Reward: 1.000000000337066
#
# Energy Harvested Per Episode:
# +-----------+--------------------+
# |   Episode |   Energy Harvested |
# +===========+====================+
# |         0 |            3971.64 |
# +-----------+--------------------+
# |         1 |            3971.64 |
# +-----------+--------------------+
# |         2 |            3971.64 |
# +-----------+--------------------+
# |         3 |            3971.64 |
# +-----------+--------------------+
# |         4 |            3971.64 |
# +-----------+--------------------+
# |         5 |            3971.64 |
# +-----------+--------------------+
# |         6 |            3971.64 |
# +-----------+--------------------+
# |         7 |            3971.64 |
# +-----------+--------------------+
# |         8 |            3971.64 |
# +-----------+--------------------+
# |         9 |            3971.64 |
# +-----------+--------------------+
# |        10 |            3971.64 |
# +-----------+--------------------+
# |        11 |            3971.64 |
# +-----------+--------------------+
# |        12 |            3971.64 |
# +-----------+--------------------+
# |        13 |            3971.64 |
# +-----------+--------------------+
# |        14 |            3971.64 |
# +-----------+--------------------+
# |        15 |            3971.64 |
# +-----------+--------------------+
# |        16 |            3971.64 |
# +-----------+--------------------+
# |        17 |            3971.64 |
# +-----------+--------------------+
# |        18 |            3971.64 |
# +-----------+--------------------+
# |        19 |            3971.64 |
# +-----------+--------------------+
# |        20 |            3971.64 |
# +-----------+--------------------+
# |        21 |            3971.64 |
# +-----------+--------------------+
# |        22 |            3971.64 |
# +-----------+--------------------+
# |        23 |            3971.64 |
# +-----------+--------------------+
# |        24 |            3971.64 |
# +-----------+--------------------+
# |        25 |            3971.64 |
# +-----------+--------------------+
# |        26 |            3971.64 |
# +-----------+--------------------+
# |        27 |            3971.64 |
# +-----------+--------------------+
# |        28 |            3971.64 |
# +-----------+--------------------+
# |        29 |            3971.64 |
# +-----------+--------------------+
# |        30 |            3971.64 |
# +-----------+--------------------+
# |        31 |            3971.64 |
# +-----------+--------------------+
# |        32 |            3971.64 |
# +-----------+--------------------+
# |        33 |            3971.64 |
# +-----------+--------------------+
# |        34 |            3971.64 |
# +-----------+--------------------+
# |        35 |            3971.64 |
# +-----------+--------------------+
# |        36 |            3971.64 |
# +-----------+--------------------+
# |        37 |            3971.64 |
# +-----------+--------------------+
# |        38 |            3971.64 |
# +-----------+--------------------+
# |        39 |            3971.64 |
# +-----------+--------------------+
# |        40 |            3971.64 |
# +-----------+--------------------+
# |        41 |            3971.64 |
# +-----------+--------------------+
# |        42 |            3971.64 |
# +-----------+--------------------+
# |        43 |            3971.64 |
# +-----------+--------------------+
# |        44 |            3971.64 |
# +-----------+--------------------+
# |        45 |            3971.64 |
# +-----------+--------------------+
# |        46 |            3971.64 |
# +-----------+--------------------+
# |        47 |            3971.64 |
# +-----------+--------------------+
# |        48 |            3971.64 |
# +-----------+--------------------+
# |        49 |            3971.64 |
# +-----------+--------------------+
# |        50 |            3971.64 |
# +-----------+--------------------+
# |        51 |            3971.64 |
# +-----------+--------------------+
# |        52 |            3971.64 |
# +-----------+--------------------+
# |        53 |            3971.64 |
# +-----------+--------------------+
# |        54 |            3971.64 |
# +-----------+--------------------+
# |        55 |            3971.64 |
# +-----------+--------------------+
# |        56 |            3971.64 |
# +-----------+--------------------+
# |        57 |            3971.64 |
# +-----------+--------------------+
# |        58 |            3971.64 |
# +-----------+--------------------+
# |        59 |            3971.64 |
# +-----------+--------------------+
# |        60 |            3971.64 |
# +-----------+--------------------+
# |        61 |            3971.64 |
# +-----------+--------------------+
# |        62 |            3971.64 |
# +-----------+--------------------+
# |        63 |            3971.64 |
# +-----------+--------------------+
# |        64 |            3971.64 |
# +-----------+--------------------+
# |        65 |            3971.64 |
# +-----------+--------------------+
# |        66 |            3971.64 |
# +-----------+--------------------+
# |        67 |            3971.64 |
# +-----------+--------------------+
# |        68 |            3971.64 |
# +-----------+--------------------+
# |        69 |            3971.64 |
# +-----------+--------------------+
# |        70 |            3971.64 |
# +-----------+--------------------+
# |        71 |            3971.64 |
# +-----------+--------------------+
# |        72 |            3971.64 |
# +-----------+--------------------+
# |        73 |            3971.64 |
# +-----------+--------------------+
# |        74 |            3971.64 |
# +-----------+--------------------+
# |        75 |            3971.64 |
# +-----------+--------------------+
# |        76 |            3971.64 |
# +-----------+--------------------+
# |        77 |            3971.64 |
# +-----------+--------------------+
# |        78 |            3971.64 |
# +-----------+--------------------+
# |        79 |            3971.64 |
# +-----------+--------------------+
# |        80 |            3971.64 |
# +-----------+--------------------+
# |        81 |            3971.64 |
# +-----------+--------------------+
# |        82 |            3971.64 |
# +-----------+--------------------+
# |        83 |            3971.64 |
# +-----------+--------------------+
# |        84 |            3971.64 |
# +-----------+--------------------+
# |        85 |            3971.64 |
# +-----------+--------------------+
# |        86 |            3971.64 |
# +-----------+--------------------+
# |        87 |            3971.64 |
# +-----------+--------------------+
# |        88 |            3971.64 |
# +-----------+--------------------+
# |        89 |            3971.64 |
# +-----------+--------------------+
# |        90 |            3971.64 |
# +-----------+--------------------+
# |        91 |            3971.64 |
# +-----------+--------------------+
# |        92 |            3971.64 |
# +-----------+--------------------+
# |        93 |            3971.64 |
# +-----------+--------------------+
# |        94 |            3971.64 |
# +-----------+--------------------+
# |        95 |            3971.64 |
# +-----------+--------------------+
# |        96 |            3971.64 |
# +-----------+--------------------+
# |        97 |            3971.64 |
# +-----------+--------------------+
# |        98 |            3971.64 |
# +-----------+--------------------+
# |        99 |            3971.64 |
# +-----------+--------------------+
#
# Phase Shifts:
# +-----------+---------------+
# |   Element |   Phase Shift |
# +===========+===============+
# |         0 |    1.06835    |
# +-----------+---------------+
# |         1 |   -0.883015   |
# +-----------+---------------+
# |         2 |   -1.84719    |
# +-----------+---------------+
# |         3 |   -1.5479     |
# +-----------+---------------+
# |         4 |    2.7907     |
# +-----------+---------------+
# |         5 |    2.57432    |
# +-----------+---------------+
# |         6 |   -2.94254    |
# +-----------+---------------+
# |         7 |   -0.929998   |
# +-----------+---------------+
# |         8 |   -1.46183    |
# +-----------+---------------+
# |         9 |    0.913346   |
# +-----------+---------------+
# |        10 |    1.5456     |
# +-----------+---------------+
# |        11 |    0.169764   |
# +-----------+---------------+
# |        12 |    2.66283    |
# +-----------+---------------+
# |        13 |    2.25234    |
# +-----------+---------------+
# |        14 |    2.95766    |
# +-----------+---------------+
# |        15 |   -1.38227    |
# +-----------+---------------+
# |        16 |   -2.48318    |
# +-----------+---------------+
# |        17 |   -3.06923    |
# +-----------+---------------+
# |        18 |   -1.51406    |
# +-----------+---------------+
# |        19 |   -1.67987    |
# +-----------+---------------+
# |        20 |    1.61654    |
# +-----------+---------------+
# |        21 |   -1.63794    |
# +-----------+---------------+
# |        22 |   -1.4938     |
# +-----------+---------------+
# |        23 |    2.47178    |
# +-----------+---------------+
# |        24 |    1.73592    |
# +-----------+---------------+
# |        25 |   -1.42028    |
# +-----------+---------------+
# |        26 |    1.99137    |
# +-----------+---------------+
# |        27 |   -1.22875    |
# +-----------+---------------+
# |        28 |    3.00171    |
# +-----------+---------------+
# |        29 |    1.31869    |
# +-----------+---------------+
# |        30 |   -1.11522    |
# +-----------+---------------+
# |        31 |   -1.16081    |
# +-----------+---------------+
# |        32 |   -0.106081   |
# +-----------+---------------+
# |        33 |   -2.37589    |
# +-----------+---------------+
# |        34 |   -1.48317    |
# +-----------+---------------+
# |        35 |   -1.87323    |
# +-----------+---------------+
# |        36 |    2.76929    |
# +-----------+---------------+
# |        37 |    0.386919   |
# +-----------+---------------+
# |        38 |   -2.48539    |
# +-----------+---------------+
# |        39 |   -0.321347   |
# +-----------+---------------+
# |        40 |    1.91029    |
# +-----------+---------------+
# |        41 |   -2.31512    |
# +-----------+---------------+
# |        42 |   -0.94079    |
# +-----------+---------------+
# |        43 |   -0.710395   |
# +-----------+---------------+
# |        44 |    2.00679    |
# +-----------+---------------+
# |        45 |   -2.90658    |
# +-----------+---------------+
# |        46 |    2.49779    |
# +-----------+---------------+
# |        47 |    2.26535    |
# +-----------+---------------+
# |        48 |    1.37119    |
# +-----------+---------------+
# |        49 |    1.18559    |
# +-----------+---------------+
# |        50 |   -2.54314    |
# +-----------+---------------+
# |        51 |   -1.65893    |
# +-----------+---------------+
# |        52 |    1.05311    |
# +-----------+---------------+
# |        53 |   -2.70478    |
# +-----------+---------------+
# |        54 |    2.73094    |
# +-----------+---------------+
# |        55 |   -2.47472    |
# +-----------+---------------+
# |        56 |   -1.1972     |
# +-----------+---------------+
# |        57 |   -2.84492    |
# +-----------+---------------+
# |        58 |    3.02169    |
# +-----------+---------------+
# |        59 |   -0.311418   |
# +-----------+---------------+
# |        60 |   -0.746013   |
# +-----------+---------------+
# |        61 |    0.039535   |
# +-----------+---------------+
# |        62 |    2.74133    |
# +-----------+---------------+
# |        63 |   -0.563626   |
# +-----------+---------------+
# |        64 |    3.11619    |
# +-----------+---------------+
# |        65 |   -2.58619    |
# +-----------+---------------+
# |        66 |   -2.5755     |
# +-----------+---------------+
# |        67 |    0.866945   |
# +-----------+---------------+
# |        68 |    2.94599    |
# +-----------+---------------+
# |        69 |    0.960014   |
# +-----------+---------------+
# |        70 |    2.90845    |
# +-----------+---------------+
# |        71 |   -1.89391    |
# +-----------+---------------+
# |        72 |   -1.99998    |
# +-----------+---------------+
# |        73 |    2.58025    |
# +-----------+---------------+
# |        74 |   -2.48751    |
# +-----------+---------------+
# |        75 |    1.24033    |
# +-----------+---------------+
# |        76 |   -2.20422    |
# +-----------+---------------+
# |        77 |   -0.310258   |
# +-----------+---------------+
# |        78 |    2.53039    |
# +-----------+---------------+
# |        79 |   -2.06926    |
# +-----------+---------------+
# |        80 |   -0.524491   |
# +-----------+---------------+
# |        81 |    2.21359    |
# +-----------+---------------+
# |        82 |   -1.60367    |
# +-----------+---------------+
# |        83 |   -2.2663     |
# +-----------+---------------+
# |        84 |   -2.60555    |
# +-----------+---------------+
# |        85 |    1.0087     |
# +-----------+---------------+
# |        86 |   -2.17956    |
# +-----------+---------------+
# |        87 |    2.62919    |
# +-----------+---------------+
# |        88 |   -2.24232    |
# +-----------+---------------+
# |        89 |   -2.08087    |
# +-----------+---------------+
# |        90 |   -0.0689504  |
# +-----------+---------------+
# |        91 |    0.212615   |
# +-----------+---------------+
# |        92 |   -0.866508   |
# +-----------+---------------+
# |        93 |   -2.55896    |
# +-----------+---------------+
# |        94 |    2.07477    |
# +-----------+---------------+
# |        95 |    0.828909   |
# +-----------+---------------+
# |        96 |    2.67401    |
# +-----------+---------------+
# |        97 |    0.846049   |
# +-----------+---------------+
# |        98 |   -0.785942   |
# +-----------+---------------+
# |        99 |    1.21288    |
# +-----------+---------------+
# |       100 |   -1.34889    |
# +-----------+---------------+
# |       101 |    2.28991    |
# +-----------+---------------+
# |       102 |   -3.00181    |
# +-----------+---------------+
# |       103 |   -2.3498     |
# +-----------+---------------+
# |       104 |    1.45289    |
# +-----------+---------------+
# |       105 |    0.230768   |
# +-----------+---------------+
# |       106 |    0.835336   |
# +-----------+---------------+
# |       107 |    1.4536     |
# +-----------+---------------+
# |       108 |   -0.636107   |
# +-----------+---------------+
# |       109 |    1.96216    |
# +-----------+---------------+
# |       110 |    2.86817    |
# +-----------+---------------+
# |       111 |    1.13667    |
# +-----------+---------------+
# |       112 |   -0.967108   |
# +-----------+---------------+
# |       113 |    0.605994   |
# +-----------+---------------+
# |       114 |    0.188257   |
# +-----------+---------------+
# |       115 |   -3.10595    |
# +-----------+---------------+
# |       116 |   -1.12344    |
# +-----------+---------------+
# |       117 |    3.08329    |
# +-----------+---------------+
# |       118 |    1.4797     |
# +-----------+---------------+
# |       119 |   -0.0583142  |
# +-----------+---------------+
# |       120 |    2.8552     |
# +-----------+---------------+
# |       121 |   -1.60337    |
# +-----------+---------------+
# |       122 |   -2.3997     |
# +-----------+---------------+
# |       123 |   -1.25054    |
# +-----------+---------------+
# |       124 |    0.192202   |
# +-----------+---------------+
# |       125 |   -2.86538    |
# +-----------+---------------+
# |       126 |    1.32727    |
# +-----------+---------------+
# |       127 |   -0.290799   |
# +-----------+---------------+
# |       128 |   -1.13836    |
# +-----------+---------------+
# |       129 |   -2.8942     |
# +-----------+---------------+
# |       130 |   -1.77195    |
# +-----------+---------------+
# |       131 |   -2.52339    |
# +-----------+---------------+
# |       132 |    3.12552    |
# +-----------+---------------+
# |       133 |    0.890589   |
# +-----------+---------------+
# |       134 |    1.56138    |
# +-----------+---------------+
# |       135 |    1.79831    |
# +-----------+---------------+
# |       136 |   -2.82795    |
# +-----------+---------------+
# |       137 |   -1.42826    |
# +-----------+---------------+
# |       138 |   -0.162391   |
# +-----------+---------------+
# |       139 |    2.44896    |
# +-----------+---------------+
# |       140 |   -0.213339   |
# +-----------+---------------+
# |       141 |   -0.742518   |
# +-----------+---------------+
# |       142 |   -0.945138   |
# +-----------+---------------+
# |       143 |    1.4156     |
# +-----------+---------------+
# |       144 |    1.61567    |
# +-----------+---------------+
# |       145 |    0.404663   |
# +-----------+---------------+
# |       146 |    3.11738    |
# +-----------+---------------+
# |       147 |   -0.700509   |
# +-----------+---------------+
# |       148 |   -1.07935    |
# +-----------+---------------+
# |       149 |    2.58886    |
# +-----------+---------------+
# |       150 |   -1.8598     |
# +-----------+---------------+
# |       151 |    0.946872   |
# +-----------+---------------+
# |       152 |   -1.48758    |
# +-----------+---------------+
# |       153 |   -1.61332    |
# +-----------+---------------+
# |       154 |    0.112558   |
# +-----------+---------------+
# |       155 |   -2.5216     |
# +-----------+---------------+
# |       156 |    0.0896887  |
# +-----------+---------------+
# |       157 |    3.09919    |
# +-----------+---------------+
# |       158 |   -2.28066    |
# +-----------+---------------+
# |       159 |    0.370497   |
# +-----------+---------------+
# |       160 |   -2.52045    |
# +-----------+---------------+
# |       161 |    2.38533    |
# +-----------+---------------+
# |       162 |    2.14971    |
# +-----------+---------------+
# |       163 |   -2.25972    |
# +-----------+---------------+
# |       164 |   -0.841087   |
# +-----------+---------------+
# |       165 |   -3.02125    |
# +-----------+---------------+
# |       166 |    2.94106    |
# +-----------+---------------+
# |       167 |   -0.712883   |
# +-----------+---------------+
# |       168 |   -2.25498    |
# +-----------+---------------+
# |       169 |   -1.77406    |
# +-----------+---------------+
# |       170 |   -0.252606   |
# +-----------+---------------+
# |       171 |    2.56908    |
# +-----------+---------------+
# |       172 |    2.3399     |
# +-----------+---------------+
# |       173 |    1.30026    |
# +-----------+---------------+
# |       174 |    1.17653    |
# +-----------+---------------+
# |       175 |   -0.502725   |
# +-----------+---------------+
# |       176 |   -1.38573    |
# +-----------+---------------+
# |       177 |   -0.412937   |
# +-----------+---------------+
# |       178 |   -0.57394    |
# +-----------+---------------+
# |       179 |    1.70534    |
# +-----------+---------------+
# |       180 |    1.54149    |
# +-----------+---------------+
# |       181 |    1.10832    |
# +-----------+---------------+
# |       182 |    0.098741   |
# +-----------+---------------+
# |       183 |    2.72768    |
# +-----------+---------------+
# |       184 |   -0.1756     |
# +-----------+---------------+
# |       185 |    0.508689   |
# +-----------+---------------+
# |       186 |   -0.300326   |
# +-----------+---------------+
# |       187 |    2.07773    |
# +-----------+---------------+
# |       188 |    2.75797    |
# +-----------+---------------+
# |       189 |    1.44048    |
# +-----------+---------------+
# |       190 |    1.00203    |
# +-----------+---------------+
# |       191 |   -2.47778    |
# +-----------+---------------+
# |       192 |   -0.303854   |
# +-----------+---------------+
# |       193 |   -1.0769     |
# +-----------+---------------+
# |       194 |   -1.95323    |
# +-----------+---------------+
# |       195 |   -2.39752    |
# +-----------+---------------+
# |       196 |    1.70352    |
# +-----------+---------------+
# |       197 |   -3.00892    |
# +-----------+---------------+
# |       198 |   -2.89796    |
# +-----------+---------------+
# |       199 |    0.210022   |
# +-----------+---------------+
# |       200 |    3.02927    |
# +-----------+---------------+
# |       201 |    2.08983    |
# +-----------+---------------+
# |       202 |    2.70207    |
# +-----------+---------------+
# |       203 |    2.54998    |
# +-----------+---------------+
# |       204 |   -1.67387    |
# +-----------+---------------+
# |       205 |   -1.24693    |
# +-----------+---------------+
# |       206 |   -0.558472   |
# +-----------+---------------+
# |       207 |    2.84426    |
# +-----------+---------------+
# |       208 |   -0.981392   |
# +-----------+---------------+
# |       209 |   -1.43034    |
# +-----------+---------------+
# |       210 |   -2.01304    |
# +-----------+---------------+
# |       211 |   -0.0111641  |
# +-----------+---------------+
# |       212 |   -1.19146    |
# +-----------+---------------+
# |       213 |   -0.19082    |
# +-----------+---------------+
# |       214 |    2.11496    |
# +-----------+---------------+
# |       215 |    2.72209    |
# +-----------+---------------+
# |       216 |    2.3511     |
# +-----------+---------------+
# |       217 |    2.30469    |
# +-----------+---------------+
# |       218 |   -2.32508    |
# +-----------+---------------+
# |       219 |    2.35438    |
# +-----------+---------------+
# |       220 |    1.8201     |
# +-----------+---------------+
# |       221 |   -0.456962   |
# +-----------+---------------+
# |       222 |    1.77235    |
# +-----------+---------------+
# |       223 |    3.01204    |
# +-----------+---------------+
# |       224 |    1.42802    |
# +-----------+---------------+
# |       225 |   -1.59545    |
# +-----------+---------------+
# |       226 |   -0.253866   |
# +-----------+---------------+
# |       227 |    2.27555    |
# +-----------+---------------+
# |       228 |    2.70676    |
# +-----------+---------------+
# |       229 |   -0.890186   |
# +-----------+---------------+
# |       230 |    2.57893    |
# +-----------+---------------+
# |       231 |   -3.09166    |
# +-----------+---------------+
# |       232 |    0.639747   |
# +-----------+---------------+
# |       233 |   -1.85948    |
# +-----------+---------------+
# |       234 |   -1.19539    |
# +-----------+---------------+
# |       235 |   -3.03093    |
# +-----------+---------------+
# |       236 |    1.56258    |
# +-----------+---------------+
# |       237 |    0.217865   |
# +-----------+---------------+
# |       238 |    3.13101    |
# +-----------+---------------+
# |       239 |   -3.08723    |
# +-----------+---------------+
# |       240 |    0.556956   |
# +-----------+---------------+
# |       241 |    0.0621947  |
# +-----------+---------------+
# |       242 |   -0.624127   |
# +-----------+---------------+
# |       243 |    0.14486    |
# +-----------+---------------+
# |       244 |    1.24848    |
# +-----------+---------------+
# |       245 |   -1.97776    |
# +-----------+---------------+
# |       246 |   -2.1601     |
# +-----------+---------------+
# |       247 |    1.86028    |
# +-----------+---------------+
# |       248 |    2.20466    |
# +-----------+---------------+
# |       249 |    1.37829    |
# +-----------+---------------+
# |       250 |    3.02084    |
# +-----------+---------------+
# |       251 |    0.597428   |
# +-----------+---------------+
# |       252 |   -2.77706    |
# +-----------+---------------+
# |       253 |   -2.14908    |
# +-----------+---------------+
# |       254 |    2.08563    |
# +-----------+---------------+
# |       255 |    2.29024    |
# +-----------+---------------+
# |       256 |   -0.401361   |
# +-----------+---------------+
# |       257 |   -1.19102    |
# +-----------+---------------+
# |       258 |    1.74901    |
# +-----------+---------------+
# |       259 |   -1.39334    |
# +-----------+---------------+
# |       260 |   -0.0361969  |
# +-----------+---------------+
# |       261 |   -0.296124   |
# +-----------+---------------+
# |       262 |    0.318731   |
# +-----------+---------------+
# |       263 |    1.43026    |
# +-----------+---------------+
# |       264 |    2.37206    |
# +-----------+---------------+
# |       265 |   -2.4368     |
# +-----------+---------------+
# |       266 |    1.35151    |
# +-----------+---------------+
# |       267 |    1.4958     |
# +-----------+---------------+
# |       268 |    1.66558    |
# +-----------+---------------+
# |       269 |    0.516437   |
# +-----------+---------------+
# |       270 |   -0.257947   |
# +-----------+---------------+
# |       271 |   -1.26136    |
# +-----------+---------------+
# |       272 |   -3.0017     |
# +-----------+---------------+
# |       273 |    2.94685    |
# +-----------+---------------+
# |       274 |   -1.9132     |
# +-----------+---------------+
# |       275 |   -1.23225    |
# +-----------+---------------+
# |       276 |   -0.744501   |
# +-----------+---------------+
# |       277 |    0.672181   |
# +-----------+---------------+
# |       278 |    1.03508    |
# +-----------+---------------+
# |       279 |   -2.6728     |
# +-----------+---------------+
# |       280 |   -0.585234   |
# +-----------+---------------+
# |       281 |   -1.57709    |
# +-----------+---------------+
# |       282 |    1.5998     |
# +-----------+---------------+
# |       283 |   -0.510311   |
# +-----------+---------------+
# |       284 |   -2.67196    |
# +-----------+---------------+
# |       285 |    0.76123    |
# +-----------+---------------+
# |       286 |   -1.34204    |
# +-----------+---------------+
# |       287 |    3.09432    |
# +-----------+---------------+
# |       288 |   -1.69591    |
# +-----------+---------------+
# |       289 |    2.8573     |
# +-----------+---------------+
# |       290 |    0.283472   |
# +-----------+---------------+
# |       291 |   -2.40766    |
# +-----------+---------------+
# |       292 |   -0.203781   |
# +-----------+---------------+
# |       293 |    0.0168313  |
# +-----------+---------------+
# |       294 |    2.02596    |
# +-----------+---------------+
# |       295 |   -0.763765   |
# +-----------+---------------+
# |       296 |   -1.68536    |
# +-----------+---------------+
# |       297 |   -2.53627    |
# +-----------+---------------+
# |       298 |    2.01228    |
# +-----------+---------------+
# |       299 |    0.775519   |
# +-----------+---------------+
# |       300 |    2.05764    |
# +-----------+---------------+
# |       301 |   -0.360626   |
# +-----------+---------------+
# |       302 |    1.51414    |
# +-----------+---------------+
# |       303 |    1.37777    |
# +-----------+---------------+
# |       304 |   -1.80311    |
# +-----------+---------------+
# |       305 |    0.0363511  |
# +-----------+---------------+
# |       306 |   -2.55479    |
# +-----------+---------------+
# |       307 |    0.192202   |
# +-----------+---------------+
# |       308 |    1.79948    |
# +-----------+---------------+
# |       309 |   -0.722229   |
# +-----------+---------------+
# |       310 |   -1.30144    |
# +-----------+---------------+
# |       311 |   -2.43185    |
# +-----------+---------------+
# |       312 |   -3.13781    |
# +-----------+---------------+
# |       313 |   -1.73911    |
# +-----------+---------------+
# |       314 |    1.60946    |
# +-----------+---------------+
# |       315 |    1.78997    |
# +-----------+---------------+
# |       316 |   -1.73036    |
# +-----------+---------------+
# |       317 |   -1.41002    |
# +-----------+---------------+
# |       318 |    1.10483    |
# +-----------+---------------+
# |       319 |   -1.45878    |
# +-----------+---------------+
# |       320 |    0.279195   |
# +-----------+---------------+
# |       321 |   -3.09759    |
# +-----------+---------------+
# |       322 |   -0.432208   |
# +-----------+---------------+
# |       323 |   -0.849653   |
# +-----------+---------------+
# |       324 |    0.505747   |
# +-----------+---------------+
# |       325 |   -3.03687    |
# +-----------+---------------+
# |       326 |   -1.72001    |
# +-----------+---------------+
# |       327 |    0.698525   |
# +-----------+---------------+
# |       328 |   -1.04613    |
# +-----------+---------------+
# |       329 |   -1.63941    |
# +-----------+---------------+
# |       330 |    0.959785   |
# +-----------+---------------+
# |       331 |    3.06114    |
# +-----------+---------------+
# |       332 |   -3.09444    |
# +-----------+---------------+
# |       333 |    1.93542    |
# +-----------+---------------+
# |       334 |    2.62933    |
# +-----------+---------------+
# |       335 |    2.02238    |
# +-----------+---------------+
# |       336 |    1.86909    |
# +-----------+---------------+
# |       337 |    0.0548097  |
# +-----------+---------------+
# |       338 |    0.51956    |
# +-----------+---------------+
# |       339 |   -1.61879    |
# +-----------+---------------+
# |       340 |   -1.04827    |
# +-----------+---------------+
# |       341 |   -1.38465    |
# +-----------+---------------+
# |       342 |    0.516146   |
# +-----------+---------------+
# |       343 |    1.64375    |
# +-----------+---------------+
# |       344 |    1.06156    |
# +-----------+---------------+
# |       345 |    0.922088   |
# +-----------+---------------+
# |       346 |    1.42564    |
# +-----------+---------------+
# |       347 |    2.39084    |
# +-----------+---------------+
# |       348 |    1.55688    |
# +-----------+---------------+
# |       349 |   -2.68161    |
# +-----------+---------------+
# |       350 |    1.30318    |
# +-----------+---------------+
# |       351 |    1.14875    |
# +-----------+---------------+
# |       352 |   -1.59662    |
# +-----------+---------------+
# |       353 |    2.10266    |
# +-----------+---------------+
# |       354 |   -2.40569    |
# +-----------+---------------+
# |       355 |    1.34987    |
# +-----------+---------------+
# |       356 |    0.315774   |
# +-----------+---------------+
# |       357 |   -1.55981    |
# +-----------+---------------+
# |       358 |    2.77089    |
# +-----------+---------------+
# |       359 |   -2.46991    |
# +-----------+---------------+
# |       360 |   -2.82544    |
# +-----------+---------------+
# |       361 |   -0.456504   |
# +-----------+---------------+
# |       362 |   -0.512596   |
# +-----------+---------------+
# |       363 |   -1.45466    |
# +-----------+---------------+
# |       364 |    0.919548   |
# +-----------+---------------+
# |       365 |    0.713425   |
# +-----------+---------------+
# |       366 |    2.69834    |
# +-----------+---------------+
# |       367 |   -0.514204   |
# +-----------+---------------+
# |       368 |   -2.50793    |
# +-----------+---------------+
# |       369 |    3.13146    |
# +-----------+---------------+
# |       370 |    2.30242    |
# +-----------+---------------+
# |       371 |   -2.87444    |
# +-----------+---------------+
# |       372 |   -2.9719     |
# +-----------+---------------+
# |       373 |    0.33657    |
# +-----------+---------------+
# |       374 |   -1.4304     |
# +-----------+---------------+
# |       375 |    1.58967    |
# +-----------+---------------+
# |       376 |   -1.20118    |
# +-----------+---------------+
# |       377 |    2.98949    |
# +-----------+---------------+
# |       378 |    0.370109   |
# +-----------+---------------+
# |       379 |   -2.40551    |
# +-----------+---------------+
# |       380 |   -2.7527     |
# +-----------+---------------+
# |       381 |    1.63384    |
# +-----------+---------------+
# |       382 |    2.96284    |
# +-----------+---------------+
# |       383 |   -1.60786    |
# +-----------+---------------+
# |       384 |   -1.67886    |
# +-----------+---------------+
# |       385 |    2.76866    |
# +-----------+---------------+
# |       386 |   -0.532261   |
# +-----------+---------------+
# |       387 |   -1.10465    |
# +-----------+---------------+
# |       388 |    1.9903     |
# +-----------+---------------+
# |       389 |   -2.27725    |
# +-----------+---------------+
# |       390 |    0.230231   |
# +-----------+---------------+
# |       391 |   -1.23662    |
# +-----------+---------------+
# |       392 |   -1.43997    |
# +-----------+---------------+
# |       393 |    3.02353    |
# +-----------+---------------+
# |       394 |   -2.62964    |
# +-----------+---------------+
# |       395 |   -1.09973    |
# +-----------+---------------+
# |       396 |    3.00385    |
# +-----------+---------------+
# |       397 |    2.59861    |
# +-----------+---------------+
# |       398 |   -1.90543    |
# +-----------+---------------+
# |       399 |    0.98641    |
# +-----------+---------------+
# |       400 |    1.95394    |
# +-----------+---------------+
# |       401 |   -2.63163    |
# +-----------+---------------+
# |       402 |    2.48945    |
# +-----------+---------------+
# |       403 |    2.31481    |
# +-----------+---------------+
# |       404 |    1.29662    |
# +-----------+---------------+
# |       405 |    0.438397   |
# +-----------+---------------+
# |       406 |   -0.849502   |
# +-----------+---------------+
# |       407 |   -3.12684    |
# +-----------+---------------+
# |       408 |    1.46132    |
# +-----------+---------------+
# |       409 |   -3.07498    |
# +-----------+---------------+
# |       410 |   -2.3616     |
# +-----------+---------------+
# |       411 |    1.99837    |
# +-----------+---------------+
# |       412 |   -2.10799    |
# +-----------+---------------+
# |       413 |    2.62441    |
# +-----------+---------------+
# |       414 |    2.93844    |
# +-----------+---------------+
# |       415 |    1.96055    |
# +-----------+---------------+
# |       416 |    0.323555   |
# +-----------+---------------+
# |       417 |   -0.83739    |
# +-----------+---------------+
# |       418 |    2.57977    |
# +-----------+---------------+
# |       419 |   -2.76485    |
# +-----------+---------------+
# |       420 |   -2.39281    |
# +-----------+---------------+
# |       421 |    0.211308   |
# +-----------+---------------+
# |       422 |    2.43447    |
# +-----------+---------------+
# |       423 |   -3.10793    |
# +-----------+---------------+
# |       424 |    2.367      |
# +-----------+---------------+
# |       425 |    0.48043    |
# +-----------+---------------+
# |       426 |    1.30637    |
# +-----------+---------------+
# |       427 |   -0.881059   |
# +-----------+---------------+
# |       428 |    1.62881    |
# +-----------+---------------+
# |       429 |    1.30127    |
# +-----------+---------------+
# |       430 |    1.72268    |
# +-----------+---------------+
# |       431 |    0.730665   |
# +-----------+---------------+
# |       432 |   -1.68733    |
# +-----------+---------------+
# |       433 |   -0.673466   |
# +-----------+---------------+
# |       434 |   -3.10661    |
# +-----------+---------------+
# |       435 |    3.10588    |
# +-----------+---------------+
# |       436 |   -2.76125    |
# +-----------+---------------+
# |       437 |    1.85828    |
# +-----------+---------------+
# |       438 |    1.62795    |
# +-----------+---------------+
# |       439 |    1.84069    |
# +-----------+---------------+
# |       440 |    0.0370755  |
# +-----------+---------------+
# |       441 |   -2.39627    |
# +-----------+---------------+
# |       442 |   -2.13824    |
# +-----------+---------------+
# |       443 |    0.381679   |
# +-----------+---------------+
# |       444 |   -2.41057    |
# +-----------+---------------+
# |       445 |   -2.60436    |
# +-----------+---------------+
# |       446 |   -1.32966    |
# +-----------+---------------+
# |       447 |    2.76073    |
# +-----------+---------------+
# |       448 |    1.54815    |
# +-----------+---------------+
# |       449 |   -1.76936    |
# +-----------+---------------+
# |       450 |   -0.0709374  |
# +-----------+---------------+
# |       451 |    2.90483    |
# +-----------+---------------+
# |       452 |    0.978603   |
# +-----------+---------------+
# |       453 |    0.783532   |
# +-----------+---------------+
# |       454 |    1.53095    |
# +-----------+---------------+
# |       455 |   -2.83688    |
# +-----------+---------------+
# |       456 |   -0.898345   |
# +-----------+---------------+
# |       457 |   -0.549835   |
# +-----------+---------------+
# |       458 |   -1.0466     |
# +-----------+---------------+
# |       459 |    1.91476    |
# +-----------+---------------+
# |       460 |   -1.71866    |
# +-----------+---------------+
# |       461 |    1.54226    |
# +-----------+---------------+
# |       462 |   -3.09135    |
# +-----------+---------------+
# |       463 |   -1.37225    |
# +-----------+---------------+
# |       464 |    2.68586    |
# +-----------+---------------+
# |       465 |   -1.13115    |
# +-----------+---------------+
# |       466 |    2.24804    |
# +-----------+---------------+
# |       467 |    2.28738    |
# +-----------+---------------+
# |       468 |    0.697132   |
# +-----------+---------------+
# |       469 |    0.738768   |
# +-----------+---------------+
# |       470 |    1.90788    |
# +-----------+---------------+
# |       471 |   -1.61849    |
# +-----------+---------------+
# |       472 |   -0.239871   |
# +-----------+---------------+
# |       473 |   -1.57067    |
# +-----------+---------------+
# |       474 |   -1.29306    |
# +-----------+---------------+
# |       475 |   -1.77073    |
# +-----------+---------------+
# |       476 |   -1.41935    |
# +-----------+---------------+
# |       477 |   -2.31928    |
# +-----------+---------------+
# |       478 |   -1.79285    |
# +-----------+---------------+
# |       479 |    0.328672   |
# +-----------+---------------+
# |       480 |    2.41309    |
# +-----------+---------------+
# |       481 |    2.72396    |
# +-----------+---------------+
# |       482 |   -2.88121    |
# +-----------+---------------+
# |       483 |    3.13404    |
# +-----------+---------------+
# |       484 |    1.66301    |
# +-----------+---------------+
# |       485 |    0.527475   |
# +-----------+---------------+
# |       486 |    2.67093    |
# +-----------+---------------+
# |       487 |    1.95536    |
# +-----------+---------------+
# |       488 |   -2.67861    |
# +-----------+---------------+
# |       489 |    1.53825    |
# +-----------+---------------+
# |       490 |   -2.08509    |
# +-----------+---------------+
# |       491 |    2.6928     |
# +-----------+---------------+
# |       492 |   -2.99504    |
# +-----------+---------------+
# |       493 |    3.0089     |
# +-----------+---------------+
# |       494 |   -0.641927   |
# +-----------+---------------+
# |       495 |    1.3166     |
# +-----------+---------------+
# |       496 |   -1.57335    |
# +-----------+---------------+
# |       497 |   -2.0554     |
# +-----------+---------------+
# |       498 |   -3.05992    |
# +-----------+---------------+
# |       499 |   -2.6823     |
# +-----------+---------------+
# |       500 |   -0.911271   |
# +-----------+---------------+
# |       501 |    1.50329    |
# +-----------+---------------+
# |       502 |    1.10531    |
# +-----------+---------------+
# |       503 |   -2.90547    |
# +-----------+---------------+
# |       504 |    2.28269    |
# +-----------+---------------+
# |       505 |    1.56137    |
# +-----------+---------------+
# |       506 |    1.16087    |
# +-----------+---------------+
# |       507 |   -0.182286   |
# +-----------+---------------+
# |       508 |    0.957863   |
# +-----------+---------------+
# |       509 |    0.72809    |
# +-----------+---------------+
# |       510 |   -2.26458    |
# +-----------+---------------+
# |       511 |    2.23629    |
# +-----------+---------------+
# |       512 |    1.65988    |
# +-----------+---------------+
# |       513 |   -2.91216    |
# +-----------+---------------+
# |       514 |    2.62439    |
# +-----------+---------------+
# |       515 |    1.421      |
# +-----------+---------------+
# |       516 |    1.8809     |
# +-----------+---------------+
# |       517 |   -2.79042    |
# +-----------+---------------+
# |       518 |    1.30018    |
# +-----------+---------------+
# |       519 |    0.500102   |
# +-----------+---------------+
# |       520 |   -2.89581    |
# +-----------+---------------+
# |       521 |    1.07604    |
# +-----------+---------------+
# |       522 |    1.70743    |
# +-----------+---------------+
# |       523 |    0.771241   |
# +-----------+---------------+
# |       524 |    2.2719     |
# +-----------+---------------+
# |       525 |   -2.51599    |
# +-----------+---------------+
# |       526 |    1.24048    |
# +-----------+---------------+
# |       527 |   -1.81065    |
# +-----------+---------------+
# |       528 |    0.969004   |
# +-----------+---------------+
# |       529 |   -2.68334    |
# +-----------+---------------+
# |       530 |    1.32224    |
# +-----------+---------------+
# |       531 |   -2.79849    |
# +-----------+---------------+
# |       532 |   -3.06489    |
# +-----------+---------------+
# |       533 |   -2.58025    |
# +-----------+---------------+
# |       534 |   -0.0248925  |
# +-----------+---------------+
# |       535 |   -0.344929   |
# +-----------+---------------+
# |       536 |   -3.12485    |
# +-----------+---------------+
# |       537 |    1.4682     |
# +-----------+---------------+
# |       538 |   -2.93998    |
# +-----------+---------------+
# |       539 |   -1.45255    |
# +-----------+---------------+
# |       540 |   -0.307177   |
# +-----------+---------------+
# |       541 |   -1.62245    |
# +-----------+---------------+
# |       542 |   -2.63507    |
# +-----------+---------------+
# |       543 |    1.45003    |
# +-----------+---------------+
# |       544 |    1.66465    |
# +-----------+---------------+
# |       545 |   -1.21938    |
# +-----------+---------------+
# |       546 |    0.713324   |
# +-----------+---------------+
# |       547 |   -2.79704    |
# +-----------+---------------+
# |       548 |    0.626235   |
# +-----------+---------------+
# |       549 |   -1.81746    |
# +-----------+---------------+
# |       550 |    2.55815    |
# +-----------+---------------+
# |       551 |    1.33019    |
# +-----------+---------------+
# |       552 |    0.382047   |
# +-----------+---------------+
# |       553 |   -0.462456   |
# +-----------+---------------+
# |       554 |    0.891987   |
# +-----------+---------------+
# |       555 |    1.81455    |
# +-----------+---------------+
# |       556 |    2.91725    |
# +-----------+---------------+
# |       557 |    0.392754   |
# +-----------+---------------+
# |       558 |   -1.97105    |
# +-----------+---------------+
# |       559 |   -2.26381    |
# +-----------+---------------+
# |       560 |   -0.298315   |
# +-----------+---------------+
# |       561 |   -1.09029    |
# +-----------+---------------+
# |       562 |    1.97742    |
# +-----------+---------------+
# |       563 |    2.93315    |
# +-----------+---------------+
# |       564 |   -2.43084    |
# +-----------+---------------+
# |       565 |    2.68167    |
# +-----------+---------------+
# |       566 |    1.99794    |
# +-----------+---------------+
# |       567 |   -1.19713    |
# +-----------+---------------+
# |       568 |   -0.853178   |
# +-----------+---------------+
# |       569 |   -1.90551    |
# +-----------+---------------+
# |       570 |   -0.291569   |
# +-----------+---------------+
# |       571 |    1.36772    |
# +-----------+---------------+
# |       572 |   -1.64353    |
# +-----------+---------------+
# |       573 |    2.12607    |
# +-----------+---------------+
# |       574 |   -2.6567     |
# +-----------+---------------+
# |       575 |    0.05495    |
# +-----------+---------------+
# |       576 |   -0.110278   |
# +-----------+---------------+
# ...
# |       765 |    0.743555   |
# +-----------+---------------+
# |       766 |   -0.965836   |
# +-----------+---------------+
# |       767 |   -0.438102   |
# +-----------+---------------+
# |       768 |   -1.71892    |
# +-----------+---------------+
# |       769 |    0.734016   |
# +-----------+---------------+
# |       770 |   -0.969461   |
# +-----------+---------------+
# |       771 |    0.840858   |
# +-----------+---------------+
# |       772 |   -2.46691    |
# +-----------+---------------+
# |       773 |    2.40449    |
# +-----------+---------------+
# |       774 |    2.79439    |
# +-----------+---------------+
# |       775 |    2.34757    |
# +-----------+---------------+
# |       776 |   -1.82928    |
# +-----------+---------------+
# |       777 |    0.968084   |
# +-----------+---------------+
# |       778 |   -0.944497   |
# +-----------+---------------+
# |       779 |   -0.286754   |
# +-----------+---------------+
# |       780 |   -0.695317   |
# +-----------+---------------+
# |       781 |    2.01836    |
# +-----------+---------------+
# |       782 |    0.612447   |
# +-----------+---------------+
# |       783 |    2.78445    |
# +-----------+---------------+
# |       784 |    1.36126    |
# +-----------+---------------+
# |       785 |   -1.72543    |
# +-----------+---------------+
# |       786 |    2.92029    |
# +-----------+---------------+
# |       787 |    0.805504   |
# +-----------+---------------+
# |       788 |    0.0805263  |
# +-----------+---------------+
# |       789 |    2.4278     |
# +-----------+---------------+
# |       790 |   -2.69113    |
# +-----------+---------------+
# |       791 |   -2.45182    |
# +-----------+---------------+
# |       792 |    2.73972    |
# +-----------+---------------+
# |       793 |    2.04939    |
# +-----------+---------------+
# |       794 |    0.08869    |
# +-----------+---------------+
# |       795 |    1.32184    |
# +-----------+---------------+
# |       796 |   -2.82176    |
# +-----------+---------------+
# |       797 |    1.17676    |
# +-----------+---------------+
# |       798 |    2.14649    |
# +-----------+---------------+
# |       799 |    0.389946   |
# +-----------+---------------+
#
# Transmit Powers for Each User:
# +--------+------------------+
# | User   |   Transmit Power |
# +========+==================+
# | User 1 |          2647.76 |
# +--------+------------------+
# | User 2 |          2647.76 |
# +--------+------------------+
# | User 3 |          2647.76 |
# +--------+------------------+
#
# UAV Positions:
# +-----------+----------------+----------------+----------------+
# |   Episode |   X-Coordinate |   Y-Coordinate |   Z-Coordinate |
# +===========+================+================+================+
# |         0 |             62 |            -11 |            100 |
# +-----------+----------------+----------------+----------------+
# |         1 |             96 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |         2 |             95 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |         3 |             94 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |         4 |            103 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |         5 |             97 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |         6 |            103 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |         7 |             99 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |         8 |            102 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |         9 |             98 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        10 |             98 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        11 |             94 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        12 |            100 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        13 |            101 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        14 |             99 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        15 |            100 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        16 |             97 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        17 |             97 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        18 |            103 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        19 |             97 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        20 |            100 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        21 |             98 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        22 |            103 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        23 |             94 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        24 |             99 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        25 |             94 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        26 |             94 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        27 |             94 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        28 |             95 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        29 |             98 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        30 |             98 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        31 |            100 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        32 |            102 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        33 |            101 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        34 |            100 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        35 |            100 |             55 |            100 |
# +-----------+----------------+----------------+----------------+
# |        36 |            102 |             55 |            100 |
# +-----------+----------------+----------------+----------------+
# |        37 |            100 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        38 |             94 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        39 |            100 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        40 |             94 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        41 |            101 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        42 |            100 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        43 |             98 |             55 |            100 |
# +-----------+----------------+----------------+----------------+
# |        44 |            103 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        45 |             97 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        46 |             96 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        47 |            100 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        48 |             94 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        49 |             96 |             55 |            100 |
# +-----------+----------------+----------------+----------------+
# |        50 |            103 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        51 |             94 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        52 |             98 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        53 |             99 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        54 |             96 |             55 |            100 |
# +-----------+----------------+----------------+----------------+
# |        55 |             96 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        56 |            102 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        57 |            101 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        58 |            103 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        59 |             97 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        60 |             95 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        61 |            100 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        62 |             94 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        63 |            103 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        64 |            100 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        65 |             99 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        66 |             97 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        67 |            100 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        68 |             98 |             55 |            100 |
# +-----------+----------------+----------------+----------------+
# |        69 |            100 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        70 |            103 |             55 |            100 |
# +-----------+----------------+----------------+----------------+
# |        71 |            102 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        72 |             97 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        73 |             97 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        74 |            102 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        75 |             97 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        76 |             99 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        77 |            100 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        78 |            100 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        79 |             97 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        80 |            103 |             55 |            100 |
# +-----------+----------------+----------------+----------------+
# |        81 |             98 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        82 |            100 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        83 |             96 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        84 |             98 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        85 |             98 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        86 |             94 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        87 |             96 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        88 |             95 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        89 |             99 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        90 |             97 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        91 |            102 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        92 |             98 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        93 |             94 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        94 |            103 |             54 |            100 |
# +-----------+----------------+----------------+----------------+
# |        95 |             98 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        96 |             95 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        97 |             96 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        98 |             96 |             55 |            100 |
# +-----------+----------------+----------------+----------------+
# |        99 |            102 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
#
# Transmit Powers for Each User in dB (Last Episode):
# +--------+-----------------------+
# | User   |   Transmit Power (dB) |
# +========+=======================+
# | User 1 |               34.2288 |
# +--------+-----------------------+
# | User 2 |               34.2288 |
# +--------+-----------------------+
# | User 3 |               34.2288 |
# +--------+-----------------------+

# %%
#Implement swipt+Phase  Shift+UAV  position using DDPG Algorithm  without  NoMA  for  100  episodes.
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
import random
import collections
from tabulate import tabulate

class CommunicationEnvironment:
    def __init__(self, max_steps):

        self.sinr_history = []
        self.efficiency_history = []
        self.stability_check_window = 10


        self.current_step = 0
        self.max_steps = max_steps
        # Channel gains
        self.H1 = np.random.rand(1, 1)
        self.h2k = np.random.rand(800, 3)


        self.R = np.random.uniform(0, 30)
        self.alpha = np.random.uniform(2, 5)
        self.beta = np.random.uniform(0, 1)


        self.M = 1
        self.N = 800
        self.K = 3
        self.power_for_energy_harvesting = np.zeros(self.K)



        self.Phi = np.exp(1j * np.random.rand(self.N) * 2 * np.pi)
        self.wi = np.random.rand(self.M, self.K)
        self.x = np.random.rand(self.M, 1)
        self.sk = np.random.rand(self.K, 1)
        self.sigma = 10**(-8/10)
        self.gamma_k = np.random.rand(self.K)
        self.B = 1e6
        self.zeta = 1.2
        self.P_BS = 10**(39/10)
        self.P_k = np.random.rand(self.K) * 10**(30/10)
        self.P_UAV = 10**(30/10)
        self.P_UE = 10**(10/10)
        self.P_RIS = self.N * 10**(0.8/10)
        self.P_RISn = 10**(0.8/10)


        self.L_BS = np.array([-200, 0, 0])
        self.Q_j = np.array([100, 50, 100])
        self.user_positions = np.array([[75, 25, 0], [125, 25, 0], [100, 75, 0]])
        self.obstacle_position = np.array([80, 40, 0])




    def reset(self):

        self.H1 = np.random.rand(1, 1)
        self.h2k = np.random.rand(800, 3)


        self.Q_j = np.array([100, 50, 100])

        self.Phi = np.exp(1j * np.random.rand(self.N) * 2 * np.pi)
        self.wi = np.random.rand(self.M, self.K)
        self.x = np.random.rand(self.M, 1)
        self.sk = np.random.rand(self.K, 1)
        self.gamma_k = np.random.rand(self.K)


        state = self._get_state()
        return state

    def _get_state(self):

        state = np.concatenate((self.H1.flatten(), self.h2k.flatten(), self.Q_j, self.user_positions.flatten()))
        return state


    def step(self, action):


        self._apply_action(action)

        previous_energy_harvested = self.get_energy_harvested()
        self._update_environment()


        self.adjust_uav_position_for_optimal_energy_harvesting()

        self._noma_power_allocation()




        reward = self._calculate_reward()


        done = self._check_done()


        new_state = self._get_state()

        return new_state, reward, done


    def adjust_uav_position_for_optimal_energy_harvesting(self):

        best_position = self.Q_j[:2]
        best_energy = self.get_energy_harvested()
        best_h2k = np.copy(self.h2k)

        for _ in range(10):
            trial_position = self.Q_j[:2] + (np.random.rand(2) - 0.5) * 10
            trial_position = self._apply_position_constraints(trial_position)


            original_position = np.copy(self.Q_j)
            self.Q_j[:2] = trial_position


            self._update_environment()


            trial_energy = self.get_energy_harvested()


            if trial_energy > best_energy:
                best_position = trial_position
                best_energy = trial_energy
                best_h2k = np.copy(self.h2k)


            self.Q_j = original_position


        self.Q_j[:2] = best_position
        self.h2k = best_h2k
        self._update_environment()









    def _apply_action(self, action):
      uav_movement = action[:2]
      phase_shift_changes = action[2:]
      new_position = self.Q_j[:2] + uav_movement
      self.Q_j[:2] = self._apply_position_constraints(new_position)


      if len(phase_shift_changes) < len(self.Phi):
        phase_shift_changes = np.concatenate([phase_shift_changes, np.zeros(len(self.Phi) - len(phase_shift_changes))])
      elif len(phase_shift_changes) > len(self.Phi):
        phase_shift_changes = phase_shift_changes[:len(self.Phi)]


      phase_shift_changes = np.array(phase_shift_changes)


      current_angles = np.angle(self.Phi)


      new_angles = (current_angles + phase_shift_changes) % (2 * np.pi)


      self.Phi = np.abs(self.Phi) * np.exp(1j * new_angles)









    def _apply_position_constraints(self, position):

        max_x, max_y = 200, 200
        min_x, min_y = -200, -200
        constrained_x = np.clip(position[0], min_x, max_x)
        constrained_y = np.clip(position[1], min_y, max_y)
        return np.array([constrained_x, constrained_y])

    def _update_environment(self):

        distance_bs_ris = np.linalg.norm(self.L_BS - self.Q_j)
        self.H1 = self._calculate_path_loss(distance_bs_ris)


        for k in range(self.K):
            distance_ris_user = np.linalg.norm(self.user_positions[k][:2] - self.Q_j[:2])
            self.h2k[:, k] = self._calculate_path_loss(distance_ris_user) * self._apply_phase_shifts(self.Phi)

        self._update_swipt_signals()










    def _calculate_path_loss(self, distance):
      frequency = 2.4e9
      c = 3e8
      path_loss_0 = 20 * np.log10(4 * np.pi * frequency / c)

      path_loss = 20 * np.log10(distance) + path_loss_0
      path_loss_linear = 10 ** (-path_loss / 10)

      return path_loss_linear



    def _apply_phase_shifts(self, phi):

        return np.exp(1j * phi)

    def _update_swipt_signals(self):

        power_split_ratio = 0.5
        self.power_for_information = self.P_k * power_split_ratio
        self.power_for_energy_harvesting = self.P_k * (1 - power_split_ratio)


    def _calculate_reward(self):

        sinr_values = []
        sorted_indices = np.argsort(self.h2k.mean(axis=0))
        for k in sorted_indices:
            signal_power = np.abs(self.h2k[:, k])**2 * self.P_k[k]
            interference_power = np.sum([np.abs(self.h2k[:, i])**2 * self.P_k[i] for i in sorted_indices if i > k])
            noise_power = self.sigma  # Using noise variance as noise power
            sinr = signal_power / (interference_power + noise_power)
            sinr_values.append(sinr)


        energy_efficiency = self._calculate_energy_efficiency()


        reward_signal_quality = np.log(1 + np.mean(sinr_values))
        total_reward = reward_signal_quality + energy_efficiency
        return total_reward

    def _calculate_signal_quality(self):


        sinr_values = []

        for k in range(self.K):


            signal_power = np.abs(self.h2k[:, k])**2


            interference_power = 1


            noise_power = self.sigma


            sinr = signal_power / (interference_power + noise_power)
            sinr_values.append(sinr)


        average_sinr = np.mean(sinr_values)


        signal_quality_reward = np.log(1 + average_sinr)

        self.sinr_history.append(signal_quality_reward)


        return signal_quality_reward


    def _calculate_energy_efficiency(self):

        total_energy_harvested = np.sum(self.power_for_energy_harvesting)


        total_energy_used = np.sum(self.power_for_information)


        if total_energy_used > 0:
            energy_efficiency = total_energy_harvested / total_energy_used
        else:
            energy_efficiency = 0


        energy_efficiency_reward = energy_efficiency

        self.efficiency_history.append(energy_efficiency_reward)

        return energy_efficiency_reward

    def _check_done(self):

        self.current_step += 1
        if self.current_step >= self.max_steps:
            return True
        return False

    def _check_stability_or_convergence(self):

        sinr_threshold = 0.01
        efficiency_threshold = 0.01


        if len(self.sinr_history) >= self.stability_check_window:
            recent_sinr_changes = np.abs(np.diff(self.sinr_history[-self.stability_check_window:]))
            recent_efficiency_changes = np.abs(np.diff(self.efficiency_history[-self.stability_check_window:]))


            if np.all(recent_sinr_changes < sinr_threshold) and np.all(recent_efficiency_changes < efficiency_threshold):
                return True

        return False

    def get_energy_harvested(self):

        return np.sum(self.power_for_energy_harvesting)

    def get_transmit_power(self):

        return self.P_k

    def get_uav_position(self):

        return self.Q_j

    def get_phase_shifts(self):

        return np.angle(self.Phi)

    def _noma_power_allocation(self):

        total_power = self.P_BS
        equal_power_allocation = total_power / self.K
        self.P_k = np.full(self.K, equal_power_allocation)





class Actor(Model):

    def __init__(self, state_size, action_size, learning_rate=0.001):
        super(Actor, self).__init__()
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate


        self.dense1 = Dense(400, input_dim=self.state_size, activation='relu')
        self.dense2 = Dense(300, activation='relu')
        self.output_layer = Dense(self.action_size, activation='tanh')  # 'tanh' for bounded actions

        self.compile(optimizer=Adam(learning_rate=self.learning_rate))

    def call(self, state):
        x = self.dense1(state)
        x = self.dense2(x)
        action = self.output_layer(x)
        return action



class Critic(Model):

    def __init__(self, state_size, action_size, learning_rate=0.001):
        super(Critic, self).__init__()
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate


        self.state_input = Input(shape=(self.state_size,))
        self.state_h1 = Dense(400, activation='relu')(self.state_input)
        self.state_h2 = Dense(300, activation='relu')(self.state_h1)


        self.action_input = Input(shape=(self.action_size,))
        self.action_h1 = Dense(300, activation='relu')(self.action_input)


        merged = tf.keras.layers.Concatenate()([self.state_h2, self.action_h1])


        self.output_layer = Dense(1, activation='linear')(merged)

        self.model = Model(inputs=[self.state_input, self.action_input], outputs=self.output_layer)
        self.optimizer = Adam(learning_rate=self.learning_rate)
        self.model.compile(loss='mse', optimizer=self.optimizer)

    def call(self, inputs):
        return self.model(inputs)

class ReplayBuffer:
    def __init__(self, buffer_size):
        self.buffer_size = buffer_size
        self.buffer = collections.deque(maxlen=buffer_size)

    def add(self, state, action, reward, next_state, done):
        experience = (state, action, reward, next_state, done)
        self.buffer.append(experience)

    def sample(self, batch_size):
        batch = random.sample(self.buffer, min(len(self.buffer), batch_size))
        states, actions, rewards, next_states, dones = map(np.stack, zip(*batch))
        return states, actions, rewards, next_states, dones

class DDPGAgent:
    def __init__(self, state_size, action_size, actor_lr, critic_lr, buffer_size, batch_size, tau=0.001):
        self.state_size = state_size
        self.action_size = action_size
        self.buffer_size = buffer_size
        self.batch_size = batch_size
        self.tau = tau

        # Initialize actor and critic networks
        self.actor = Actor(state_size, action_size, actor_lr)
        self.critic = Critic(state_size, action_size, critic_lr)


        self.target_actor = Actor(state_size, action_size, actor_lr)
        self.target_critic = Critic(state_size, action_size, critic_lr)


        self.replay_buffer = ReplayBuffer(buffer_size)


        self.update_target_networks()

    def update_target_networks(self):

        self._soft_update(self.actor, self.target_actor)
        self._soft_update(self.critic, self.target_critic)

    def _soft_update(self, model, target_model):
        for target_param, param in zip(target_model.trainable_variables, model.trainable_variables):
            target_param.assign(self.tau * param + (1 - self.tau) * target_param)

    def learn(self):

        states, actions, rewards, next_states, dones = self.replay_buffer.sample(self.batch_size)


        target_actions = self.target_actor(states)
        target_critic_values = self.target_critic([next_states, target_actions])
        target_q_values = rewards + (1 - dones) * 0.99 * target_critic_values



        with tf.GradientTape() as tape:
            critic_values = self.critic([states, actions])
            critic_loss = tf.reduce_mean(tf.square(target_q_values - critic_values))
        critic_grad = tape.gradient(critic_loss, self.critic.trainable_variables)
        self.critic.optimizer.apply_gradients(zip(critic_grad, self.critic.trainable_variables))




        with tf.GradientTape() as tape:
            actions_pred = self.actor(states)
            critic_values_pred = self.critic([states, actions_pred])

            actor_loss = -tf.math.reduce_mean(critic_values_pred)
        actor_grad = tape.gradient(actor_loss, self.actor.trainable_variables)
        self.actor.optimizer.apply_gradients(zip(actor_grad, self.actor.trainable_variables))



    def act(self, states):

        actions = self.actor(states)

        clipped_actions = tf.clip_by_value(actions, -1, 1)
        return clipped_actions


    def update_target(self):

        actor_weights = self.actor.get_weights()
        target_actor_weights = self.target_actor.get_weights()
        for i in range(len(actor_weights)):
            target_actor_weights[i] = tau * actor_weights[i] + (1 - tau) * target_actor_weights[i]
        self.target_actor.set_weights(target_actor_weights)


        critic_weights = self.critic.get_weights()
        target_critic_weights = self.target_critic.get_weights()
        for i in range(len(critic_weights)):
            target_critic_weights[i] = tau * critic_weights[i] + (1 - tau) * target_critic_weights[i]
        self.target_critic.set_weights(target_critic_weights)




env = CommunicationEnvironment(max_steps=100)
state = env.reset()
state_size = len(state)
action_size = len(env.Phi)

tau = 0.001



agent = DDPGAgent(state_size, action_size, actor_lr=0.001, critic_lr=0.002, buffer_size=100000, batch_size=64, tau=tau)


agent = DDPGAgent(state_size, action_size, actor_lr=0.001, critic_lr=0.002, buffer_size=100000, batch_size=64, tau=tau)

energy_harvested_per_episode = []
transmit_powers = []
phase_shifts = []
uav_positions = []


for episode in range(100):
    state = env.reset()
    total_reward = 0
    done = False

    while not done:
        action = agent.act(np.array([state]))[0]  # Need to pass a batch of states
        next_state, reward, done = env.step(action)
        agent.replay_buffer.add(state, action, reward, next_state, done)
        agent.learn()
        state = next_state
        total_reward += reward

    agent.update_target_networks()
    print(f"Episode: {episode}, Total Reward: {total_reward}")


    energy_harvested_per_episode.append(env.get_energy_harvested())
    uav_positions.append(env.get_uav_position())
    if episode == 99:
      transmit_powers = env.get_transmit_power()
      phase_shifts = env.get_phase_shifts()

print("\nEnergy Harvested Per Episode:")
print(tabulate([[i, eh] for i, eh in enumerate(energy_harvested_per_episode)], headers=["Episode", "Energy Harvested"], tablefmt="grid"))



print("\nPhase Shifts:")
print(tabulate([[i, ps] for i, ps in enumerate(phase_shifts)], headers=["Element", "Phase Shift"], tablefmt="grid"))
print("\nTransmit Powers for Each User:")
print(tabulate([[f"User {i+1}", tp] for i, tp in enumerate(env.P_k)], headers=["User", "Transmit Power"], tablefmt="grid"))

print("\nUAV Positions:")
print(tabulate([[i] + list(pos) for i, pos in enumerate(uav_positions)], headers=["Episode", "X-Coordinate", "Y-Coordinate", "Z-Coordinate"], tablefmt="grid"))


max_energy_harvested = max(energy_harvested_per_episode)
energy_harvested_ratio = [eh / max_energy_harvested for eh in energy_harvested_per_episode]



transmit_powers_db = 10 * np.log10(transmit_powers)


print("\nTransmit Powers for Each User in dB (Last Episode):")
print(tabulate([[f"User {i+1}", tp_db] for i, tp_db in enumerate(transmit_powers_db)], headers=["User", "Transmit Power (dB)"], tablefmt="grid"))
# Out:
# <ipython-input-1-6ce512d95475>:203: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.h2k[:, k] = self._calculate_path_loss(distance_ris_user) * self._apply_phase_shifts(self.Phi)
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7bb274f42200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7bb274f42200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Episode: 0, Total Reward: 100.0000017759907
# Episode: 1, Total Reward: 1.0000000004598406
# Episode: 2, Total Reward: 1.000000000281451
# Episode: 3, Total Reward: 1.0000000004127776
# Episode: 4, Total Reward: 1.0000000002912957
# Episode: 5, Total Reward: 1.0000000002687626
# Episode: 6, Total Reward: 1.0000000002918337
# Episode: 7, Total Reward: 1.000000000454482
# Episode: 8, Total Reward: 1.000000000357567
# Episode: 9, Total Reward: 1.000000000382368
# Episode: 10, Total Reward: 1.0000000004479213
# Episode: 11, Total Reward: 1.0000000003624763
# Episode: 12, Total Reward: 1.000000000434033
# Episode: 13, Total Reward: 1.000000000449163
# Episode: 14, Total Reward: 1.0000000002784735
# Episode: 15, Total Reward: 1.0000000003250415
# Episode: 16, Total Reward: 1.0000000003427487
# Episode: 17, Total Reward: 1.0000000002700424
# Episode: 18, Total Reward: 1.0000000002821672
# Episode: 19, Total Reward: 1.000000000256978
# Episode: 20, Total Reward: 1.0000000003386658
# Episode: 21, Total Reward: 1.0000000003881646
# Episode: 22, Total Reward: 1.0000000004693954
# Episode: 23, Total Reward: 1.000000000488725
# Episode: 24, Total Reward: 1.0000000002750224
# Episode: 25, Total Reward: 1.0000000002917786
# Episode: 26, Total Reward: 1.0000000002707001
# Episode: 27, Total Reward: 1.0000000003690712
# Episode: 28, Total Reward: 1.00000000030328
# Episode: 29, Total Reward: 1.0000000003770027
# Episode: 30, Total Reward: 1.0000000004867147
# Episode: 31, Total Reward: 1.000000000260258
# Episode: 32, Total Reward: 1.0000000002736094
# Episode: 33, Total Reward: 1.0000000002764218
# Episode: 34, Total Reward: 1.000000000288337
# Episode: 35, Total Reward: 1.0000000003350418
# Episode: 36, Total Reward: 1.0000000003016716
# Episode: 37, Total Reward: 1.0000000004217837
# Episode: 38, Total Reward: 1.0000000003627585
# Episode: 39, Total Reward: 1.0000000003616476
# Episode: 40, Total Reward: 1.0000000004528773
# Episode: 41, Total Reward: 1.000000000438302
# Episode: 42, Total Reward: 1.0000000002572151
# Episode: 43, Total Reward: 1.0000000003593117
# Episode: 44, Total Reward: 1.0000000003609624
# Episode: 45, Total Reward: 1.0000000003310645
# Episode: 46, Total Reward: 1.0000000003502811
# Episode: 47, Total Reward: 1.0000000002986231
# Episode: 48, Total Reward: 1.0000000002772318
# Episode: 49, Total Reward: 1.0000000003976155
# Episode: 50, Total Reward: 1.0000000004781027
# Episode: 51, Total Reward: 1.0000000004515592
# Episode: 52, Total Reward: 1.0000000002717409
# Episode: 53, Total Reward: 1.0000000003658305
# Episode: 54, Total Reward: 1.00000000031443
# Episode: 55, Total Reward: 1.000000000357109
# Episode: 56, Total Reward: 1.0000000003149285
# Episode: 57, Total Reward: 1.0000000003141192
# Episode: 58, Total Reward: 1.0000000002802267
# Episode: 59, Total Reward: 1.000000000277603
# Episode: 60, Total Reward: 1.0000000003181746
# Episode: 61, Total Reward: 1.0000000004098268
# Episode: 62, Total Reward: 1.0000000002969556
# Episode: 63, Total Reward: 1.000000000303931
# Episode: 64, Total Reward: 1.0000000003657623
# Episode: 65, Total Reward: 1.0000000003265654
# Episode: 66, Total Reward: 1.0000000003638887
# Episode: 67, Total Reward: 1.0000000003114542
# Episode: 68, Total Reward: 1.000000000298905
# Episode: 69, Total Reward: 1.000000000263004
# Episode: 70, Total Reward: 1.000000000279083
# Episode: 71, Total Reward: 1.0000000003494842
# Episode: 72, Total Reward: 1.0000000003102358
# Episode: 73, Total Reward: 1.000000000407632
# Episode: 74, Total Reward: 1.000000000364539
# Episode: 75, Total Reward: 1.0000000003714418
# Episode: 76, Total Reward: 1.0000000003103517
# Episode: 77, Total Reward: 1.0000000002910368
# Episode: 78, Total Reward: 1.0000000002817462
# Episode: 79, Total Reward: 1.00000000035359
# Episode: 80, Total Reward: 1.0000000003635006
# Episode: 81, Total Reward: 1.0000000004875638
# Episode: 82, Total Reward: 1.0000000003060063
# Episode: 83, Total Reward: 1.00000000026959
# Episode: 84, Total Reward: 1.0000000002817242
# Episode: 85, Total Reward: 1.000000000417086
# Episode: 86, Total Reward: 1.0000000002710048
# Episode: 87, Total Reward: 1.0000000003836704
# Episode: 88, Total Reward: 1.0000000003157357
# Episode: 89, Total Reward: 1.000000000315099
# Episode: 90, Total Reward: 1.0000000003340073
# Episode: 91, Total Reward: 1.00000000043151
# Episode: 92, Total Reward: 1.000000000320991
# Episode: 93, Total Reward: 1.000000000291248
# Episode: 94, Total Reward: 1.0000000004475298
# Episode: 95, Total Reward: 1.0000000003683809
# Episode: 96, Total Reward: 1.0000000002897786
# Episode: 97, Total Reward: 1.0000000003700942
# Episode: 98, Total Reward: 1.0000000003390384
# Episode: 99, Total Reward: 1.0000000002703129
#
# Energy Harvested Per Episode:
# +-----------+--------------------+
# |   Episode |   Energy Harvested |
# +===========+====================+
# |         0 |            3971.64 |
# +-----------+--------------------+
# |         1 |            3971.64 |
# +-----------+--------------------+
# |         2 |            3971.64 |
# +-----------+--------------------+
# |         3 |            3971.64 |
# +-----------+--------------------+
# |         4 |            3971.64 |
# +-----------+--------------------+
# |         5 |            3971.64 |
# +-----------+--------------------+
# |         6 |            3971.64 |
# +-----------+--------------------+
# |         7 |            3971.64 |
# +-----------+--------------------+
# |         8 |            3971.64 |
# +-----------+--------------------+
# |         9 |            3971.64 |
# +-----------+--------------------+
# |        10 |            3971.64 |
# +-----------+--------------------+
# |        11 |            3971.64 |
# +-----------+--------------------+
# |        12 |            3971.64 |
# +-----------+--------------------+
# |        13 |            3971.64 |
# +-----------+--------------------+
# |        14 |            3971.64 |
# +-----------+--------------------+
# |        15 |            3971.64 |
# +-----------+--------------------+
# |        16 |            3971.64 |
# +-----------+--------------------+
# |        17 |            3971.64 |
# +-----------+--------------------+
# |        18 |            3971.64 |
# +-----------+--------------------+
# |        19 |            3971.64 |
# +-----------+--------------------+
# |        20 |            3971.64 |
# +-----------+--------------------+
# |        21 |            3971.64 |
# +-----------+--------------------+
# |        22 |            3971.64 |
# +-----------+--------------------+
# |        23 |            3971.64 |
# +-----------+--------------------+
# |        24 |            3971.64 |
# +-----------+--------------------+
# |        25 |            3971.64 |
# +-----------+--------------------+
# |        26 |            3971.64 |
# +-----------+--------------------+
# |        27 |            3971.64 |
# +-----------+--------------------+
# |        28 |            3971.64 |
# +-----------+--------------------+
# |        29 |            3971.64 |
# +-----------+--------------------+
# |        30 |            3971.64 |
# +-----------+--------------------+
# |        31 |            3971.64 |
# +-----------+--------------------+
# |        32 |            3971.64 |
# +-----------+--------------------+
# |        33 |            3971.64 |
# +-----------+--------------------+
# |        34 |            3971.64 |
# +-----------+--------------------+
# |        35 |            3971.64 |
# +-----------+--------------------+
# |        36 |            3971.64 |
# +-----------+--------------------+
# |        37 |            3971.64 |
# +-----------+--------------------+
# |        38 |            3971.64 |
# +-----------+--------------------+
# |        39 |            3971.64 |
# +-----------+--------------------+
# |        40 |            3971.64 |
# +-----------+--------------------+
# |        41 |            3971.64 |
# +-----------+--------------------+
# |        42 |            3971.64 |
# +-----------+--------------------+
# |        43 |            3971.64 |
# +-----------+--------------------+
# |        44 |            3971.64 |
# +-----------+--------------------+
# |        45 |            3971.64 |
# +-----------+--------------------+
# |        46 |            3971.64 |
# +-----------+--------------------+
# |        47 |            3971.64 |
# +-----------+--------------------+
# |        48 |            3971.64 |
# +-----------+--------------------+
# |        49 |            3971.64 |
# +-----------+--------------------+
# |        50 |            3971.64 |
# +-----------+--------------------+
# |        51 |            3971.64 |
# +-----------+--------------------+
# |        52 |            3971.64 |
# +-----------+--------------------+
# |        53 |            3971.64 |
# +-----------+--------------------+
# |        54 |            3971.64 |
# +-----------+--------------------+
# |        55 |            3971.64 |
# +-----------+--------------------+
# |        56 |            3971.64 |
# +-----------+--------------------+
# |        57 |            3971.64 |
# +-----------+--------------------+
# |        58 |            3971.64 |
# +-----------+--------------------+
# |        59 |            3971.64 |
# +-----------+--------------------+
# |        60 |            3971.64 |
# +-----------+--------------------+
# |        61 |            3971.64 |
# +-----------+--------------------+
# |        62 |            3971.64 |
# +-----------+--------------------+
# |        63 |            3971.64 |
# +-----------+--------------------+
# |        64 |            3971.64 |
# +-----------+--------------------+
# |        65 |            3971.64 |
# +-----------+--------------------+
# |        66 |            3971.64 |
# +-----------+--------------------+
# |        67 |            3971.64 |
# +-----------+--------------------+
# |        68 |            3971.64 |
# +-----------+--------------------+
# |        69 |            3971.64 |
# +-----------+--------------------+
# |        70 |            3971.64 |
# +-----------+--------------------+
# |        71 |            3971.64 |
# +-----------+--------------------+
# |        72 |            3971.64 |
# +-----------+--------------------+
# |        73 |            3971.64 |
# +-----------+--------------------+
# |        74 |            3971.64 |
# +-----------+--------------------+
# |        75 |            3971.64 |
# +-----------+--------------------+
# |        76 |            3971.64 |
# +-----------+--------------------+
# |        77 |            3971.64 |
# +-----------+--------------------+
# |        78 |            3971.64 |
# +-----------+--------------------+
# |        79 |            3971.64 |
# +-----------+--------------------+
# |        80 |            3971.64 |
# +-----------+--------------------+
# |        81 |            3971.64 |
# +-----------+--------------------+
# |        82 |            3971.64 |
# +-----------+--------------------+
# |        83 |            3971.64 |
# +-----------+--------------------+
# |        84 |            3971.64 |
# +-----------+--------------------+
# |        85 |            3971.64 |
# +-----------+--------------------+
# |        86 |            3971.64 |
# +-----------+--------------------+
# |        87 |            3971.64 |
# +-----------+--------------------+
# |        88 |            3971.64 |
# +-----------+--------------------+
# |        89 |            3971.64 |
# +-----------+--------------------+
# |        90 |            3971.64 |
# +-----------+--------------------+
# |        91 |            3971.64 |
# +-----------+--------------------+
# |        92 |            3971.64 |
# +-----------+--------------------+
# |        93 |            3971.64 |
# +-----------+--------------------+
# |        94 |            3971.64 |
# +-----------+--------------------+
# |        95 |            3971.64 |
# +-----------+--------------------+
# |        96 |            3971.64 |
# +-----------+--------------------+
# |        97 |            3971.64 |
# +-----------+--------------------+
# |        98 |            3971.64 |
# +-----------+--------------------+
# |        99 |            3971.64 |
# +-----------+--------------------+
#
# Phase Shifts:
# +-----------+---------------+
# |   Element |   Phase Shift |
# +===========+===============+
# |         0 |   -0.366636   |
# +-----------+---------------+
# |         1 |   -1.87462    |
# +-----------+---------------+
# |         2 |   -0.814249   |
# +-----------+---------------+
# |         3 |    2.59173    |
# +-----------+---------------+
# |         4 |   -0.5654     |
# +-----------+---------------+
# |         5 |   -2.36502    |
# +-----------+---------------+
# |         6 |    2.55991    |
# +-----------+---------------+
# |         7 |   -0.235446   |
# +-----------+---------------+
# |         8 |   -1.28968    |
# +-----------+---------------+
# |         9 |    0.291166   |
# +-----------+---------------+
# |        10 |    0.983303   |
# +-----------+---------------+
# |        11 |    3.04032    |
# +-----------+---------------+
# |        12 |    2.19356    |
# +-----------+---------------+
# |        13 |   -0.445557   |
# +-----------+---------------+
# |        14 |   -0.949101   |
# +-----------+---------------+
# |        15 |    2.13268    |
# +-----------+---------------+
# |        16 |    2.24899    |
# +-----------+---------------+
# |        17 |    0.112278   |
# +-----------+---------------+
# |        18 |   -2.80625    |
# +-----------+---------------+
# |        19 |   -2.07023    |
# +-----------+---------------+
# |        20 |    1.12468    |
# +-----------+---------------+
# |        21 |    2.97365    |
# +-----------+---------------+
# |        22 |   -0.791577   |
# +-----------+---------------+
# |        23 |    1.1361     |
# +-----------+---------------+
# |        24 |    0.0975348  |
# +-----------+---------------+
# |        25 |   -0.644272   |
# +-----------+---------------+
# |        26 |   -0.130449   |
# +-----------+---------------+
# |        27 |    2.09146    |
# +-----------+---------------+
# |        28 |   -0.963622   |
# +-----------+---------------+
# |        29 |    0.487993   |
# +-----------+---------------+
# |        30 |   -2.25215    |
# +-----------+---------------+
# |        31 |   -2.26254    |
# +-----------+---------------+
# |        32 |    0.95074    |
# +-----------+---------------+
# |        33 |   -2.37189    |
# +-----------+---------------+
# |        34 |    1.53138    |
# +-----------+---------------+
# |        35 |    0.0437359  |
# +-----------+---------------+
# |        36 |    0.308659   |
# +-----------+---------------+
# |        37 |    1.23766    |
# +-----------+---------------+
# |        38 |   -2.7256     |
# +-----------+---------------+
# |        39 |    0.923932   |
# +-----------+---------------+
# |        40 |    2.04205    |
# +-----------+---------------+
# |        41 |    1.45475    |
# +-----------+---------------+
# |        42 |    1.24204    |
# +-----------+---------------+
# |        43 |    1.20065    |
# +-----------+---------------+
# |        44 |    0.941675   |
# +-----------+---------------+
# |        45 |    2.22557    |
# +-----------+---------------+
# |        46 |   -0.24256    |
# +-----------+---------------+
# |        47 |    0.821378   |
# +-----------+---------------+
# |        48 |   -2.12737    |
# +-----------+---------------+
# |        49 |   -1.15336    |
# +-----------+---------------+
# |        50 |    1.18333    |
# +-----------+---------------+
# |        51 |    0.649412   |
# +-----------+---------------+
# |        52 |   -0.553273   |
# +-----------+---------------+
# |        53 |    2.84188    |
# +-----------+---------------+
# |        54 |   -0.294533   |
# +-----------+---------------+
# |        55 |    0.950145   |
# +-----------+---------------+
# |        56 |    2.07919    |
# +-----------+---------------+
# |        57 |   -0.0423751  |
# +-----------+---------------+
# |        58 |    2.75385    |
# +-----------+---------------+
# |        59 |    0.0559561  |
# +-----------+---------------+
# |        60 |   -2.56877    |
# +-----------+---------------+
# |        61 |    2.42343    |
# +-----------+---------------+
# |        62 |   -0.808997   |
# +-----------+---------------+
# |        63 |   -1.20262    |
# +-----------+---------------+
# |        64 |    1.85248    |
# +-----------+---------------+
# |        65 |    1.6071     |
# +-----------+---------------+
# |        66 |    1.07915    |
# +-----------+---------------+
# |        67 |   -1.55077    |
# +-----------+---------------+
# |        68 |    1.85765    |
# +-----------+---------------+
# |        69 |    1.09898    |
# +-----------+---------------+
# |        70 |    0.366306   |
# +-----------+---------------+
# |        71 |    1.5345     |
# +-----------+---------------+
# |        72 |    1.46721    |
# +-----------+---------------+
# |        73 |    1.66297    |
# +-----------+---------------+
# |        74 |   -0.489517   |
# +-----------+---------------+
# |        75 |   -2.40351    |
# +-----------+---------------+
# |        76 |    0.28238    |
# +-----------+---------------+
# |        77 |    0.250982   |
# +-----------+---------------+
# |        78 |    3.07888    |
# +-----------+---------------+
# |        79 |   -0.836069   |
# +-----------+---------------+
# |        80 |   -2.11552    |
# +-----------+---------------+
# |        81 |    0.492978   |
# +-----------+---------------+
# |        82 |    0.834418   |
# +-----------+---------------+
# |        83 |   -1.8853     |
# +-----------+---------------+
# |        84 |    0.355705   |
# +-----------+---------------+
# |        85 |   -2.14178    |
# +-----------+---------------+
# |        86 |    2.36369    |
# +-----------+---------------+
# |        87 |   -0.52463    |
# +-----------+---------------+
# |        88 |   -0.593833   |
# +-----------+---------------+
# |        89 |    1.16582    |
# +-----------+---------------+
# |        90 |    1.82425    |
# +-----------+---------------+
# |        91 |    0.190055   |
# +-----------+---------------+
# |        92 |   -0.42285    |
# +-----------+---------------+
# |        93 |    1.38915    |
# +-----------+---------------+
# |        94 |    1.14229    |
# +-----------+---------------+
# |        95 |   -1.45631    |
# +-----------+---------------+
# |        96 |    0.560944   |
# +-----------+---------------+
# |        97 |    1.32726    |
# +-----------+---------------+
# |        98 |   -0.933589   |
# +-----------+---------------+
# |        99 |    3.10169    |
# +-----------+---------------+
# |       100 |    2.83509    |
# +-----------+---------------+
# |       101 |    1.44966    |
# +-----------+---------------+
# |       102 |   -1.87111    |
# +-----------+---------------+
# |       103 |    0.175563   |
# +-----------+---------------+
# |       104 |    2.76586    |
# +-----------+---------------+
# |       105 |   -3.11894    |
# +-----------+---------------+
# |       106 |    2.2164     |
# +-----------+---------------+
# |       107 |    2.81256    |
# +-----------+---------------+
# |       108 |    1.83582    |
# +-----------+---------------+
# |       109 |   -0.806242   |
# +-----------+---------------+
# |       110 |   -0.513937   |
# +-----------+---------------+
# |       111 |    2.66094    |
# +-----------+---------------+
# |       112 |    1.2462     |
# +-----------+---------------+
# |       113 |   -3.05528    |
# +-----------+---------------+
# |       114 |    0.795681   |
# +-----------+---------------+
# |       115 |    0.303322   |
# +-----------+---------------+
# |       116 |   -2.47792    |
# +-----------+---------------+
# |       117 |   -3.00451    |
# +-----------+---------------+
# |       118 |   -1.27874    |
# +-----------+---------------+
# |       119 |    2.83984    |
# +-----------+---------------+
# |       120 |   -0.979456   |
# +-----------+---------------+
# |       121 |    1.48765    |
# +-----------+---------------+
# |       122 |   -2.99382    |
# +-----------+---------------+
# |       123 |    2.59493    |
# +-----------+---------------+
# |       124 |    1.18708    |
# +-----------+---------------+
# |       125 |   -2.04628    |
# +-----------+---------------+
# |       126 |    0.26317    |
# +-----------+---------------+
# |       127 |    2.54779    |
# +-----------+---------------+
# |       128 |   -2.72121    |
# +-----------+---------------+
# |       129 |   -1.68696    |
# +-----------+---------------+
# |       130 |    2.05096    |
# +-----------+---------------+
# |       131 |    2.71625    |
# +-----------+---------------+
# |       132 |   -0.346664   |
# +-----------+---------------+
# |       133 |    3.09894    |
# +-----------+---------------+
# |       134 |    1.23628    |
# +-----------+---------------+
# |       135 |   -2.41471    |
# +-----------+---------------+
# |       136 |    2.85821    |
# +-----------+---------------+
# |       137 |   -0.289271   |
# +-----------+---------------+
# |       138 |    0.203121   |
# +-----------+---------------+
# |       139 |   -2.89035    |
# +-----------+---------------+
# |       140 |    0.789405   |
# +-----------+---------------+
# |       141 |   -0.351533   |
# +-----------+---------------+
# |       142 |   -1.45589    |
# +-----------+---------------+
# |       143 |   -3.08817    |
# +-----------+---------------+
# |       144 |   -2.49511    |
# +-----------+---------------+
# |       145 |    1.62244    |
# +-----------+---------------+
# |       146 |    0.374765   |
# +-----------+---------------+
# |       147 |   -2.90821    |
# +-----------+---------------+
# |       148 |   -1.64587    |
# +-----------+---------------+
# |       149 |   -1.08036    |
# +-----------+---------------+
# |       150 |    0.887747   |
# +-----------+---------------+
# |       151 |   -2.99824    |
# +-----------+---------------+
# |       152 |    1.18692    |
# +-----------+---------------+
# |       153 |   -2.13509    |
# +-----------+---------------+
# |       154 |   -0.665025   |
# +-----------+---------------+
# |       155 |   -2.47253    |
# +-----------+---------------+
# |       156 |    0.20361    |
# +-----------+---------------+
# |       157 |   -2.81578    |
# +-----------+---------------+
# |       158 |    3.06171    |
# +-----------+---------------+
# |       159 |   -1.76592    |
# +-----------+---------------+
# |       160 |    2.67721    |
# +-----------+---------------+
# |       161 |    0.880159   |
# +-----------+---------------+
# |       162 |    0.36822    |
# +-----------+---------------+
# |       163 |    2.87536    |
# +-----------+---------------+
# |       164 |   -0.775309   |
# +-----------+---------------+
# |       165 |    1.20605    |
# +-----------+---------------+
# |       166 |    2.71768    |
# +-----------+---------------+
# |       167 |   -1.30736    |
# +-----------+---------------+
# |       168 |   -2.91851    |
# +-----------+---------------+
# |       169 |   -0.399609   |
# +-----------+---------------+
# |       170 |   -1.50714    |
# +-----------+---------------+
# |       171 |   -2.41504    |
# +-----------+---------------+
# |       172 |   -0.431424   |
# +-----------+---------------+
# |       173 |    0.341211   |
# +-----------+---------------+
# |       174 |    1.17979    |
# +-----------+---------------+
# |       175 |   -2.55516    |
# +-----------+---------------+
# |       176 |   -0.421498   |
# +-----------+---------------+
# |       177 |    3.11388    |
# +-----------+---------------+
# |       178 |   -1.60111    |
# +-----------+---------------+
# |       179 |    1.81413    |
# +-----------+---------------+
# |       180 |   -2.97498    |
# +-----------+---------------+
# |       181 |    1.32013    |
# +-----------+---------------+
# |       182 |    2.12795    |
# +-----------+---------------+
# |       183 |    2.95923    |
# +-----------+---------------+
# |       184 |   -0.598186   |
# +-----------+---------------+
# |       185 |    0.263446   |
# +-----------+---------------+
# |       186 |    2.92148    |
# +-----------+---------------+
# |       187 |    1.07961    |
# +-----------+---------------+
# |       188 |    2.10552    |
# +-----------+---------------+
# |       189 |    0.750471   |
# +-----------+---------------+
# |       190 |   -2.26007    |
# +-----------+---------------+
# |       191 |   -1.56483    |
# +-----------+---------------+
# |       192 |    1.05523    |
# +-----------+---------------+
# |       193 |   -0.190308   |
# +-----------+---------------+
# |       194 |   -2.32344    |
# +-----------+---------------+
# |       195 |   -1.2431     |
# +-----------+---------------+
# |       196 |    1.74943    |
# +-----------+---------------+
# |       197 |   -0.73736    |
# +-----------+---------------+
# |       198 |   -2.75081    |
# +-----------+---------------+
# |       199 |    2.38544    |
# +-----------+---------------+
# |       200 |   -1.30684    |
# +-----------+---------------+
# |       201 |   -1.04905    |
# +-----------+---------------+
# |       202 |   -1.48412    |
# +-----------+---------------+
# |       203 |    2.44246    |
# +-----------+---------------+
# |       204 |   -1.70736    |
# +-----------+---------------+
# |       205 |    1.44017    |
# +-----------+---------------+
# |       206 |    2.59476    |
# +-----------+---------------+
# |       207 |    0.161503   |
# +-----------+---------------+
# |       208 |   -3.05731    |
# +-----------+---------------+
# |       209 |   -2.7381     |
# +-----------+---------------+
# |       210 |   -1.0003     |
# +-----------+---------------+
# |       211 |    2.39562    |
# +-----------+---------------+
# |       212 |   -3.09069    |
# +-----------+---------------+
# |       213 |    0.461043   |
# +-----------+---------------+
# |       214 |    0.264239   |
# +-----------+---------------+
# |       215 |    0.719605   |
# +-----------+---------------+
# |       216 |    0.289856   |
# +-----------+---------------+
# |       217 |   -0.654036   |
# +-----------+---------------+
# |       218 |   -0.502429   |
# +-----------+---------------+
# |       219 |    1.12931    |
# +-----------+---------------+
# |       220 |   -1.65749    |
# +-----------+---------------+
# |       221 |    2.76008    |
# +-----------+---------------+
# |       222 |    0.792637   |
# +-----------+---------------+
# |       223 |    3.10065    |
# +-----------+---------------+
# |       224 |   -1.26979    |
# +-----------+---------------+
# |       225 |    1.08009    |
# +-----------+---------------+
# |       226 |    0.477836   |
# +-----------+---------------+
# |       227 |    0.138319   |
# +-----------+---------------+
# |       228 |    0.939647   |
# +-----------+---------------+
# |       229 |    1.99908    |
# +-----------+---------------+
# |       230 |   -2.00247    |
# +-----------+---------------+
# |       231 |   -1.29645    |
# +-----------+---------------+
# |       232 |   -1.51271    |
# +-----------+---------------+
# |       233 |   -2.92391    |
# +-----------+---------------+
# |       234 |   -2.13271    |
# +-----------+---------------+
# |       235 |   -0.273159   |
# +-----------+---------------+
# |       236 |   -1.0827     |
# +-----------+---------------+
# |       237 |    1.99562    |
# +-----------+---------------+
# |       238 |    0.711619   |
# +-----------+---------------+
# |       239 |    0.0745883  |
# +-----------+---------------+
# |       240 |    2.46066    |
# +-----------+---------------+
# |       241 |    0.380703   |
# +-----------+---------------+
# |       242 |    2.79324    |
# +-----------+---------------+
# |       243 |   -0.79429    |
# +-----------+---------------+
# |       244 |    1.68978    |
# +-----------+---------------+
# |       245 |    2.37836    |
# +-----------+---------------+
# |       246 |    1.60678    |
# +-----------+---------------+
# |       247 |    1.6057     |
# +-----------+---------------+
# |       248 |    3.13526    |
# +-----------+---------------+
# |       249 |    1.47516    |
# +-----------+---------------+
# |       250 |   -2.75289    |
# +-----------+---------------+
# |       251 |   -2.57627    |
# +-----------+---------------+
# |       252 |    2.35759    |
# +-----------+---------------+
# |       253 |    0.682306   |
# +-----------+---------------+
# |       254 |   -2.88866    |
# +-----------+---------------+
# |       255 |   -1.37663    |
# +-----------+---------------+
# |       256 |   -2.5353     |
# +-----------+---------------+
# |       257 |   -2.63247    |
# +-----------+---------------+
# |       258 |    2.54576    |
# +-----------+---------------+
# |       259 |    1.19323    |
# +-----------+---------------+
# |       260 |    1.72995    |
# +-----------+---------------+
# |       261 |   -0.446857   |
# +-----------+---------------+
# |       262 |    2.33465    |
# +-----------+---------------+
# |       263 |   -0.350158   |
# +-----------+---------------+
# |       264 |    1.21752    |
# +-----------+---------------+
# |       265 |    1.57497    |
# +-----------+---------------+
# |       266 |    2.44514    |
# +-----------+---------------+
# |       267 |   -2.55865    |
# +-----------+---------------+
# |       268 |    1.24524    |
# +-----------+---------------+
# |       269 |    0.972038   |
# +-----------+---------------+
# |       270 |    2.99501    |
# +-----------+---------------+
# |       271 |    2.7974     |
# +-----------+---------------+
# |       272 |   -0.307066   |
# +-----------+---------------+
# |       273 |    0.758854   |
# +-----------+---------------+
# |       274 |    0.72895    |
# +-----------+---------------+
# |       275 |    0.418719   |
# +-----------+---------------+
# |       276 |   -1.26301    |
# +-----------+---------------+
# |       277 |   -1.4289     |
# +-----------+---------------+
# |       278 |    2.32606    |
# +-----------+---------------+
# |       279 |    1.88743    |
# +-----------+---------------+
# |       280 |    0.747657   |
# +-----------+---------------+
# |       281 |    1.98747    |
# +-----------+---------------+
# |       282 |    1.13323    |
# +-----------+---------------+
# |       283 |   -1.06907    |
# +-----------+---------------+
# |       284 |    0.604537   |
# +-----------+---------------+
# |       285 |    1.24067    |
# +-----------+---------------+
# |       286 |    1.68854    |
# +-----------+---------------+
# |       287 |   -1.1084     |
# +-----------+---------------+
# |       288 |   -2.56119    |
# +-----------+---------------+
# |       289 |   -1.94517    |
# +-----------+---------------+
# |       290 |   -1.85378    |
# +-----------+---------------+
# |       291 |   -1.63604    |
# +-----------+---------------+
# |       292 |    2.24785    |
# +-----------+---------------+
# |       293 |    1.76926    |
# +-----------+---------------+
# |       294 |   -1.02097    |
# +-----------+---------------+
# |       295 |    0.676555   |
# +-----------+---------------+
# |       296 |   -1.0323     |
# +-----------+---------------+
# |       297 |   -2.52913    |
# +-----------+---------------+
# |       298 |   -0.501354   |
# +-----------+---------------+
# |       299 |   -1.66208    |
# +-----------+---------------+
# |       300 |    2.29938    |
# +-----------+---------------+
# |       301 |   -2.89366    |
# +-----------+---------------+
# |       302 |    0.827982   |
# +-----------+---------------+
# |       303 |   -2.00972    |
# +-----------+---------------+
# |       304 |    2.50939    |
# +-----------+---------------+
# |       305 |   -1.14046    |
# +-----------+---------------+
# |       306 |   -2.20054    |
# +-----------+---------------+
# |       307 |    2.95609    |
# +-----------+---------------+
# |       308 |   -0.124233   |
# +-----------+---------------+
# |       309 |   -1.06224    |
# +-----------+---------------+
# |       310 |    2.29531    |
# +-----------+---------------+
# |       311 |   -0.880617   |
# +-----------+---------------+
# |       312 |   -1.92864    |
# +-----------+---------------+
# |       313 |    2.71525    |
# +-----------+---------------+
# |       314 |   -0.85048    |
# +-----------+---------------+
# |       315 |    2.58157    |
# +-----------+---------------+
# |       316 |   -3.0246     |
# +-----------+---------------+
# |       317 |    0.768221   |
# +-----------+---------------+
# |       318 |   -2.86711    |
# +-----------+---------------+
# |       319 |    2.10287    |
# +-----------+---------------+
# |       320 |    1.03263    |
# +-----------+---------------+
# |       321 |   -1.34437    |
# +-----------+---------------+
# |       322 |   -2.99208    |
# +-----------+---------------+
# |       323 |   -0.6665     |
# +-----------+---------------+
# |       324 |    0.833397   |
# +-----------+---------------+
# |       325 |   -1.50188    |
# +-----------+---------------+
# |       326 |    1.06599    |
# +-----------+---------------+
# |       327 |    0.669798   |
# +-----------+---------------+
# |       328 |   -2.69808    |
# +-----------+---------------+
# |       329 |    1.23713    |
# +-----------+---------------+
# |       330 |    1.88974    |
# +-----------+---------------+
# |       331 |   -1.55022    |
# +-----------+---------------+
# |       332 |   -0.742382   |
# +-----------+---------------+
# |       333 |    1.37288    |
# +-----------+---------------+
# |       334 |    2.66397    |
# +-----------+---------------+
# |       335 |   -1.85565    |
# +-----------+---------------+
# |       336 |    1.77212    |
# +-----------+---------------+
# |       337 |    2.56449    |
# +-----------+---------------+
# |       338 |   -2.04745    |
# +-----------+---------------+
# |       339 |   -1.39412    |
# +-----------+---------------+
# |       340 |    0.492225   |
# +-----------+---------------+
# |       341 |   -0.860022   |
# +-----------+---------------+
# |       342 |   -1.39835    |
# +-----------+---------------+
# |       343 |   -0.169101   |
# +-----------+---------------+
# |       344 |   -0.35574    |
# +-----------+---------------+
# |       345 |   -0.892526   |
# +-----------+---------------+
# |       346 |    2.52223    |
# +-----------+---------------+
# |       347 |    1.46659    |
# +-----------+---------------+
# |       348 |   -0.087919   |
# +-----------+---------------+
# |       349 |   -0.190988   |
# +-----------+---------------+
# |       350 |    0.556351   |
# +-----------+---------------+
# |       351 |    2.82116    |
# +-----------+---------------+
# |       352 |    1.08068    |
# +-----------+---------------+
# |       353 |   -0.515742   |
# +-----------+---------------+
# |       354 |   -0.795598   |
# +-----------+---------------+
# |       355 |   -3.11916    |
# +-----------+---------------+
# |       356 |   -2.67244    |
# +-----------+---------------+
# |       357 |    0.780632   |
# +-----------+---------------+
# |       358 |   -2.32629    |
# +-----------+---------------+
# |       359 |    2.53145    |
# +-----------+---------------+
# |       360 |    0.294678   |
# +-----------+---------------+
# |       361 |   -2.58883    |
# +-----------+---------------+
# |       362 |    2.86835    |
# +-----------+---------------+
# |       363 |   -1.35287    |
# +-----------+---------------+
# |       364 |    1.0659     |
# +-----------+---------------+
# |       365 |   -0.364965   |
# +-----------+---------------+
# |       366 |    2.83591    |
# +-----------+---------------+
# |       367 |    3.05344    |
# +-----------+---------------+
# |       368 |    2.62382    |
# +-----------+---------------+
# |       369 |   -2.84389    |
# +-----------+---------------+
# |       370 |   -2.75021    |
# +-----------+---------------+
# |       371 |    2.88189    |
# +-----------+---------------+
# |       372 |    1.47523    |
# +-----------+---------------+
# |       373 |    2.87434    |
# +-----------+---------------+
# |       374 |    2.06637    |
# +-----------+---------------+
# |       375 |   -1.14934    |
# +-----------+---------------+
# |       376 |    1.20784    |
# +-----------+---------------+
# |       377 |   -2.26914    |
# +-----------+---------------+
# |       378 |   -1.96489    |
# +-----------+---------------+
# |       379 |    0.266938   |
# +-----------+---------------+
# |       380 |   -2.57592    |
# +-----------+---------------+
# |       381 |    1.19603    |
# +-----------+---------------+
# |       382 |   -0.968945   |
# +-----------+---------------+
# |       383 |    1.59237    |
# +-----------+---------------+
# |       384 |    2.56223    |
# +-----------+---------------+
# |       385 |    1.96985    |
# +-----------+---------------+
# |       386 |    0.822261   |
# +-----------+---------------+
# |       387 |   -2.91902    |
# +-----------+---------------+
# |       388 |   -0.864934   |
# +-----------+---------------+
# |       389 |   -2.26181    |
# +-----------+---------------+
# |       390 |   -2.54954    |
# +-----------+---------------+
# |       391 |    2.37253    |
# +-----------+---------------+
# |       392 |    1.6796     |
# +-----------+---------------+
# |       393 |    1.44928    |
# +-----------+---------------+
# |       394 |    2.52629    |
# +-----------+---------------+
# |       395 |    0.409083   |
# +-----------+---------------+
# |       396 |   -0.158738   |
# +-----------+---------------+
# |       397 |   -2.84385    |
# +-----------+---------------+
# |       398 |   -1.80372    |
# +-----------+---------------+
# |       399 |   -0.00149196 |
# +-----------+---------------+
# |       400 |   -0.0525362  |
# +-----------+---------------+
# |       401 |   -2.73781    |
# +-----------+---------------+
# |       402 |   -2.64299    |
# +-----------+---------------+
# |       403 |    1.20983    |
# +-----------+---------------+
# |       404 |   -0.656423   |
# +-----------+---------------+
# |       405 |    0.979586   |
# +-----------+---------------+
# |       406 |    0.128107   |
# +-----------+---------------+
# |       407 |    2.15149    |
# +-----------+---------------+
# |       408 |    0.671958   |
# +-----------+---------------+
# |       409 |   -2.73653    |
# +-----------+---------------+
# |       410 |   -1.02485    |
# +-----------+---------------+
# |       411 |    1.04951    |
# +-----------+---------------+
# |       412 |    0.0794346  |
# +-----------+---------------+
# |       413 |   -1.09342    |
# +-----------+---------------+
# |       414 |    2.4073     |
# +-----------+---------------+
# |       415 |    2.81573    |
# +-----------+---------------+
# |       416 |    1.89264    |
# +-----------+---------------+
# |       417 |    1.81155    |
# +-----------+---------------+
# |       418 |    0.183104   |
# +-----------+---------------+
# |       419 |    2.20043    |
# +-----------+---------------+
# |       420 |   -3.01049    |
# +-----------+---------------+
# |       421 |    1.13151    |
# +-----------+---------------+
# |       422 |    1.70131    |
# +-----------+---------------+
# |       423 |    1.63028    |
# +-----------+---------------+
# |       424 |   -2.99518    |
# +-----------+---------------+
# |       425 |    0.676476   |
# +-----------+---------------+
# |       426 |   -1.30595    |
# +-----------+---------------+
# |       427 |   -0.38583    |
# +-----------+---------------+
# |       428 |    2.4991     |
# +-----------+---------------+
# |       429 |    1.76648    |
# +-----------+---------------+
# |       430 |   -1.90595    |
# +-----------+---------------+
# |       431 |    0.188236   |
# +-----------+---------------+
# |       432 |   -0.476403   |
# +-----------+---------------+
# |       433 |   -0.159622   |
# +-----------+---------------+
# |       434 |   -1.73289    |
# +-----------+---------------+
# |       435 |    0.405298   |
# +-----------+---------------+
# |       436 |    2.62855    |
# +-----------+---------------+
# |       437 |    2.96409    |
# +-----------+---------------+
# |       438 |    0.222158   |
# +-----------+---------------+
# |       439 |   -1.82035    |
# +-----------+---------------+
# |       440 |   -0.337297   |
# +-----------+---------------+
# |       441 |    2.31596    |
# +-----------+---------------+
# |       442 |    1.63327    |
# +-----------+---------------+
# |       443 |    1.6908     |
# +-----------+---------------+
# |       444 |    0.942522   |
# +-----------+---------------+
# |       445 |   -0.63893    |
# +-----------+---------------+
# |       446 |   -1.55337    |
# +-----------+---------------+
# |       447 |    2.01738    |
# +-----------+---------------+
# |       448 |    0.476651   |
# +-----------+---------------+
# |       449 |   -0.499331   |
# +-----------+---------------+
# |       450 |   -1.13393    |
# +-----------+---------------+
# |       451 |   -0.81676    |
# +-----------+---------------+
# |       452 |    0.808692   |
# +-----------+---------------+
# |       453 |    0.617671   |
# +-----------+---------------+
# |       454 |   -1.74977    |
# +-----------+---------------+
# |       455 |    2.09754    |
# +-----------+---------------+
# |       456 |   -2.87611    |
# +-----------+---------------+
# |       457 |    2.02438    |
# +-----------+---------------+
# |       458 |   -0.122523   |
# +-----------+---------------+
# |       459 |   -2.12493    |
# +-----------+---------------+
# |       460 |   -1.61421    |
# +-----------+---------------+
# |       461 |    2.31453    |
# +-----------+---------------+
# |       462 |   -3.06557    |
# +-----------+---------------+
# |       463 |    2.84505    |
# +-----------+---------------+
# |       464 |    2.77719    |
# +-----------+---------------+
# |       465 |   -0.662358   |
# +-----------+---------------+
# |       466 |   -2.94125    |
# +-----------+---------------+
# |       467 |   -0.45127    |
# +-----------+---------------+
# |       468 |    2.35044    |
# +-----------+---------------+
# |       469 |   -2.10285    |
# +-----------+---------------+
# |       470 |   -1.85113    |
# +-----------+---------------+
# |       471 |    1.52985    |
# +-----------+---------------+
# |       472 |   -0.641201   |
# +-----------+---------------+
# |       473 |    0.815242   |
# +-----------+---------------+
# |       474 |    2.81678    |
# +-----------+---------------+
# |       475 |    1.20753    |
# +-----------+---------------+
# |       476 |    2.99117    |
# +-----------+---------------+
# |       477 |   -0.373037   |
# +-----------+---------------+
# |       478 |   -0.674519   |
# +-----------+---------------+
# |       479 |   -2.1404     |
# +-----------+---------------+
# |       480 |   -0.231961   |
# +-----------+---------------+
# |       481 |   -2.60493    |
# +-----------+---------------+
# |       482 |   -2.41422    |
# +-----------+---------------+
# |       483 |   -2.39885    |
# +-----------+---------------+
# |       484 |    0.542686   |
# +-----------+---------------+
# |       485 |   -2.19162    |
# +-----------+---------------+
# |       486 |    3.0975     |
# +-----------+---------------+
# |       487 |    1.83377    |
# +-----------+---------------+
# |       488 |    2.58067    |
# +-----------+---------------+
# |       489 |   -1.98892    |
# +-----------+---------------+
# |       490 |   -0.394442   |
# +-----------+---------------+
# |       491 |    0.00723143 |
# +-----------+---------------+
# |       492 |    1.93613    |
# +-----------+---------------+
# |       493 |    1.25137    |
# +-----------+---------------+
# |       494 |   -1.49189    |
# +-----------+---------------+
# |       495 |   -0.177665   |
# +-----------+---------------+
# |       496 |    2.82548    |
# +-----------+---------------+
# |       497 |    0.703927   |
# +-----------+---------------+
# |       498 |   -1.04221    |
# +-----------+---------------+
# |       499 |   -0.529691   |
# +-----------+---------------+
# |       500 |   -2.68536    |
# +-----------+---------------+
# |       501 |    2.24921    |
# +-----------+---------------+
# |       502 |    0.149356   |
# +-----------+---------------+
# |       503 |   -1.83284    |
# +-----------+---------------+
# |       504 |   -2.63355    |
# +-----------+---------------+
# |       505 |   -0.760927   |
# +-----------+---------------+
# |       506 |    1.70783    |
# +-----------+---------------+
# |       507 |    2.60059    |
# +-----------+---------------+
# |       508 |    0.993519   |
# +-----------+---------------+
# |       509 |   -1.82959    |
# +-----------+---------------+
# |       510 |    1.22249    |
# +-----------+---------------+
# |       511 |   -0.915488   |
# +-----------+---------------+
# |       512 |    1.18308    |
# +-----------+---------------+
# |       513 |    1.17145    |
# +-----------+---------------+
# |       514 |    1.08931    |
# +-----------+---------------+
# |       515 |   -2.77118    |
# +-----------+---------------+
# |       516 |   -3.12808    |
# +-----------+---------------+
# |       517 |    0.0333602  |
# +-----------+---------------+
# |       518 |   -3.05506    |
# +-----------+---------------+
# |       519 |    0.693581   |
# +-----------+---------------+
# |       520 |    0.490594   |
# +-----------+---------------+
# |       521 |   -0.673936   |
# +-----------+---------------+
# |       522 |   -0.659468   |
# +-----------+---------------+
# |       523 |    2.09105    |
# +-----------+---------------+
# |       524 |    1.76712    |
# +-----------+---------------+
# |       525 |   -0.147471   |
# +-----------+---------------+
# |       526 |   -2.09852    |
# +-----------+---------------+
# |       527 |   -2.4182     |
# +-----------+---------------+
# |       528 |    0.608495   |
# +-----------+---------------+
# |       529 |    1.17936    |
# +-----------+---------------+
# |       530 |   -0.613795   |
# +-----------+---------------+
# |       531 |    2.69746    |
# +-----------+---------------+
# |       532 |   -1.28162    |
# +-----------+---------------+
# |       533 |   -0.218035   |
# +-----------+---------------+
# |       534 |   -1.03718    |
# +-----------+---------------+
# |       535 |    3.06874    |
# +-----------+---------------+
# |       536 |    2.60894    |
# +-----------+---------------+
# |       537 |   -2.618      |
# +-----------+---------------+
# |       538 |    3.10835    |
# +-----------+---------------+
# |       539 |    2.1719     |
# +-----------+---------------+
# |       540 |    2.30558    |
# +-----------+---------------+
# |       541 |    0.166929   |
# +-----------+---------------+
# |       542 |   -1.2287     |
# +-----------+---------------+
# |       543 |   -0.5608     |
# +-----------+---------------+
# |       544 |    0.0883965  |
# +-----------+---------------+
# |       545 |   -1.80206    |
# +-----------+---------------+
# |       546 |    1.87727    |
# +-----------+---------------+
# |       547 |    1.45408    |
# +-----------+---------------+
# |       548 |    1.61881    |
# +-----------+---------------+
# |       549 |    1.47246    |
# +-----------+---------------+
# |       550 |    0.590385   |
# +-----------+---------------+
# |       551 |    2.5713     |
# +-----------+---------------+
# |       552 |   -2.49781    |
# +-----------+---------------+
# |       553 |   -1.10646    |
# +-----------+---------------+
# |       554 |    3.0547     |
# +-----------+---------------+
# |       555 |   -0.949742   |
# +-----------+---------------+
# |       556 |    0.145747   |
# +-----------+---------------+
# |       557 |   -0.463131   |
# +-----------+---------------+
# |       558 |    0.850272   |
# +-----------+---------------+
# |       559 |   -2.59397    |
# +-----------+---------------+
# |       560 |    0.302495   |
# +-----------+---------------+
# |       561 |   -1.85532    |
# +-----------+---------------+
# |       562 |   -0.0395122  |
# +-----------+---------------+
# |       563 |    0.737323   |
# +-----------+---------------+
# |       564 |   -0.186618   |
# +-----------+---------------+
# |       565 |   -1.50381    |
# +-----------+---------------+
# |       566 |    3.00135    |
# +-----------+---------------+
# |       567 |    2.33393    |
# +-----------+---------------+
# |       568 |    2.26973    |
# +-----------+---------------+
# |       569 |   -2.04862    |
# +-----------+---------------+
# |       570 |   -1.58856    |
# +-----------+---------------+
# |       571 |    0.0772268  |
# +-----------+---------------+
# |       572 |   -0.740168   |
# +-----------+---------------+
# |       573 |   -1.83622    |
# +-----------+---------------+
# |       574 |   -2.31522    |
# +-----------+---------------+
# |       575 |    0.94313    |
# +-----------+---------------+
# |       576 |   -1.47483    |
# +-----------+---------------+
# ...
# |       765 |   -1.54339    |
# +-----------+---------------+
# |       766 |    3.09785    |
# +-----------+---------------+
# |       767 |   -0.762064   |
# +-----------+---------------+
# |       768 |    3.12398    |
# +-----------+---------------+
# |       769 |   -2.3178     |
# +-----------+---------------+
# |       770 |    2.91278    |
# +-----------+---------------+
# |       771 |   -2.14107    |
# +-----------+---------------+
# |       772 |   -3.05517    |
# +-----------+---------------+
# |       773 |    1.89788    |
# +-----------+---------------+
# |       774 |   -1.56588    |
# +-----------+---------------+
# |       775 |    1.2638     |
# +-----------+---------------+
# |       776 |   -1.21948    |
# +-----------+---------------+
# |       777 |   -2.80666    |
# +-----------+---------------+
# |       778 |    2.19252    |
# +-----------+---------------+
# |       779 |   -0.544576   |
# +-----------+---------------+
# |       780 |   -1.09305    |
# +-----------+---------------+
# |       781 |   -1.51673    |
# +-----------+---------------+
# |       782 |   -0.316712   |
# +-----------+---------------+
# |       783 |   -2.87602    |
# +-----------+---------------+
# |       784 |   -2.37686    |
# +-----------+---------------+
# |       785 |   -0.687157   |
# +-----------+---------------+
# |       786 |   -0.239035   |
# +-----------+---------------+
# |       787 |   -0.693009   |
# +-----------+---------------+
# |       788 |   -2.70299    |
# +-----------+---------------+
# |       789 |    2.79409    |
# +-----------+---------------+
# |       790 |   -2.35855    |
# +-----------+---------------+
# |       791 |   -2.49133    |
# +-----------+---------------+
# |       792 |    1.96618    |
# +-----------+---------------+
# |       793 |   -2.01131    |
# +-----------+---------------+
# |       794 |   -2.47571    |
# +-----------+---------------+
# |       795 |   -1.82845    |
# +-----------+---------------+
# |       796 |    2.82387    |
# +-----------+---------------+
# |       797 |   -0.78548    |
# +-----------+---------------+
# |       798 |   -2.99097    |
# +-----------+---------------+
# |       799 |   -0.223353   |
# +-----------+---------------+
#
# Transmit Powers for Each User:
# +--------+------------------+
# | User   |   Transmit Power |
# +========+==================+
# | User 1 |          2647.76 |
# +--------+------------------+
# | User 2 |          2647.76 |
# +--------+------------------+
# | User 3 |          2647.76 |
# +--------+------------------+
#
# UAV Positions:
# +-----------+----------------+----------------+----------------+
# |   Episode |   X-Coordinate |   Y-Coordinate |   Z-Coordinate |
# +===========+================+================+================+
# |         0 |            134 |             24 |            100 |
# +-----------+----------------+----------------+----------------+
# |         1 |             98 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |         2 |             99 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |         3 |            101 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |         4 |             98 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |         5 |             98 |             44 |            100 |
# +-----------+----------------+----------------+----------------+
# |         6 |            103 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |         7 |            100 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |         8 |            105 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |         9 |             97 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        10 |             96 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        11 |            105 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        12 |             97 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        13 |            102 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        14 |            104 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        15 |             97 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        16 |            103 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        17 |            100 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |        18 |            102 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        19 |             99 |             44 |            100 |
# +-----------+----------------+----------------+----------------+
# |        20 |            103 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        21 |             98 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        22 |            101 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        23 |            102 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        24 |            101 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        25 |             97 |             44 |            100 |
# +-----------+----------------+----------------+----------------+
# |        26 |             96 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |        27 |             97 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        28 |            102 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        29 |             97 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        30 |            100 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        31 |            101 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |        32 |             99 |             44 |            100 |
# +-----------+----------------+----------------+----------------+
# |        33 |            102 |             44 |            100 |
# +-----------+----------------+----------------+----------------+
# |        34 |            105 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        35 |            105 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        36 |            100 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        37 |             99 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        38 |            105 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        39 |            100 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        40 |             98 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        41 |            105 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        42 |             99 |             44 |            100 |
# +-----------+----------------+----------------+----------------+
# |        43 |             96 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        44 |             96 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        45 |            103 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        46 |            103 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        47 |            104 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        48 |             97 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        49 |            101 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        50 |            103 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        51 |             96 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        52 |             99 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        53 |            102 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        54 |            102 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        55 |            103 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        56 |            103 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        57 |            101 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        58 |            101 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        59 |             99 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |        60 |            100 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        61 |             98 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        62 |             96 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |        63 |             96 |             44 |            100 |
# +-----------+----------------+----------------+----------------+
# |        64 |            101 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        65 |            102 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        66 |             98 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        67 |             99 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        68 |            105 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        69 |             97 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |        70 |            105 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |        71 |             97 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        72 |             99 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |        73 |             97 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        74 |            101 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        75 |             97 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        76 |            101 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        77 |            104 |             46 |            100 |
# +-----------+----------------+----------------+----------------+
# |        78 |            101 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        79 |             96 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        80 |             96 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        81 |            103 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        82 |            102 |             44 |            100 |
# +-----------+----------------+----------------+----------------+
# |        83 |            101 |             44 |            100 |
# +-----------+----------------+----------------+----------------+
# |        84 |             99 |             47 |            100 |
# +-----------+----------------+----------------+----------------+
# |        85 |            105 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        86 |            101 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |        87 |            100 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        88 |             98 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        89 |            100 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
# |        90 |            103 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        91 |            103 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        92 |            103 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        93 |            102 |             49 |            100 |
# +-----------+----------------+----------------+----------------+
# |        94 |            103 |             53 |            100 |
# +-----------+----------------+----------------+----------------+
# |        95 |            103 |             52 |            100 |
# +-----------+----------------+----------------+----------------+
# |        96 |             99 |             45 |            100 |
# +-----------+----------------+----------------+----------------+
# |        97 |             96 |             50 |            100 |
# +-----------+----------------+----------------+----------------+
# |        98 |            105 |             51 |            100 |
# +-----------+----------------+----------------+----------------+
# |        99 |             99 |             48 |            100 |
# +-----------+----------------+----------------+----------------+
#
# Transmit Powers for Each User in dB (Last Episode):
# +--------+-----------------------+
# | User   |   Transmit Power (dB) |
# +========+=======================+
# | User 1 |               34.2288 |
# +--------+-----------------------+
# | User 2 |               34.2288 |
# +--------+-----------------------+
# | User 3 |               34.2288 |
# +--------+-----------------------+

# %%
#Genetic  algorithm  without  noma
import numpy as np

class GeneticAlgorithm:
    def __init__(self, population_size, num_elements, mutation_rate=0.01):
        self.population_size = population_size
        self.num_elements = num_elements
        self.mutation_rate = mutation_rate
        self.population = [np.random.uniform(0, 2*np.pi, num_elements) for _ in range(population_size)]

    def evaluate(self, environment, individual):
        # Temporarily apply phase shifts to evaluate performance
        original_phases = environment.Phi.copy()
        environment.Phi = np.exp(1j * individual)
        reward = environment.calculate_reward_based_on_phases()  # You need to implement this method
        environment.Phi = original_phases
        return reward

    def select(self, environment):
        fitness_scores = [self.evaluate(environment, ind) for ind in self.population]
        sorted_indices = np.argsort(fitness_scores)
        return [self.population[idx] for idx in sorted_indices[-2:]]  # Select the best two configurations

    def crossover(self, parent1, parent2):
        child = np.array([parent1[i] if np.random.rand() < 0.5 else parent2[i] for i in range(self.num_elements)])
        return child

    def mutate(self, individual):
        for i in range(self.num_elements):
            if np.random.rand() < self.mutation_rate:
                individual[i] += np.random.normal(0, 0.1)  # Small mutation
        return individual

    def run_generation(self, environment):
        new_population = []
        parents = self.select(environment)
        for _ in range(self.population_size // 2):
            child1 = self.crossover(parents[0], parents[1])
            child2 = self.crossover(parents[0], parents[1])
            new_population.append(self.mutate(child1))
            new_population.append(self.mutate(child2))
        self.population = new_population
        return self.evaluate(environment, self.population[0])

# %%
import matplotlib.pyplot as plt

# Correctly sized data lists
episodes = list(range(100))  # Episodes from 0 to 99
x_coordinates = [
  62, 96, 95, 94, 103, 97, 103, 99, 102, 98,
98, 94, 100, 101, 99, 100, 97, 103, 97, 100, 98, 103, 94, 99, 94, 101,
 94, 95, 98, 98, 100, 102, 101, 100, 102, 100, 94, 96, 94, 100, 103, 98,
  98, 97, 94, 100, 94, 97, 100, 94, 98, 102, 99, 94, 103, 98, 100,
97, 103, 95, 94, 97, 100, 103, 97, 94, 96, 96, 102, 94, 98, 99, 96,
  102, 99, 97, 103, 98, 100, 96, 98, 94, 102, 98, 100, 96, 98, 94, 102,
  97, 102, 94, 103, 98, 95, 96, 96, 102, 95, 94
]
y_coordinates = [
   -11, 45, 47, 51, 52, 46, 50, 52, 48, 46,
47, 49, 51, 47, 53, 49, 47, 48, 47, 48, 48, 53, 46, 52, 51, 54,
   54, 47, 47, 54, 47, 51, 54, 52, 55, 52, 48, 53, 48, 52, 50, 53,
   52, 48, 55, 54, 47, 48, 51, 51, 46, 50, 55, 52, 54, 55, 47,
   54, 52, 49, 50, 54, 49, 55, 48, 55, 50, 51, 51, 51, 46, 54, 55,
   48, 53, 49, 55, 49, 53, 52, 49, 52, 47, 55, 49, 51, 50, 47, 52,
   46, 52, 53, 54, 47, 51, 52, 55, 50, 51, 50
]

# Plotting with adjustments and marking the final position
plt.figure(figsize=(10, 4))  # Increase figure size for better visibility
plt.scatter(x_coordinates, y_coordinates, color='blue', s=50)  # Blue dots for all positions
plt.scatter([x_coordinates[-1]], [y_coordinates[-1]], color='red', s=100, label='Final Position')  # Red dot for the final position
plt.title('UAV X and Y Coordinates')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.xlim(90, 110)  # Adjusting the x-axis limits to focus on the main cluster
plt.ylim(40, 60)   # Adjusting the y-axis limits to focus on the main cluster
plt.grid(True)
plt.legend()  # Adding a legend to identify the final position
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import matplotlib.pyplot as plt

# Define the coordinates and labels
points = {
    'Base Station': (-200, 0),
    'UAV-RIS': (100, 50),
    'Obstacle': (80, 40),
    'UT1': (75, 25),
    'UT2': (125, 25),
    'UT3': (100, 75),
    'UAV-RIS DDPG with NOMA': (102, 50),
    'Genetic Algorithm with NOMA': (99, 53),
    'DDPG without NOMA': (94, 44),
    'Genetic Algorithm without NOMA': (102, 47)
}

# Colors for each point
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 'orange', 'purple', 'brown']

# Create the plot
plt.figure(figsize=(10, 6))

# Adding points to the plot
for (label, (x, y)), color in zip(points.items(), colors):
    plt.scatter(x, y, color=color, s=100, label=label)

# Adding labels to the points
for label, (x, y) in points.items():
    plt.text(x, y, f' {label}', fontsize=9)

# Set plot title and labels
plt.title('Coordinates Plot with Different Colors')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')

# Show legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the coordinates and labels
points = {
    'Base Station': {'coords': (45, 30), 'color': 'blue', 'marker': '^'},  # Using a triangle marker
    'UAV-RIS': {'coords': (100, 50), 'color': 'orange', 'marker': 'v'},     # Triangle marker, pointing down
    'Obstacle': {'coords': (80, 40), 'color': 'red', 'marker': 'X'},       # Using 'X' for danger
    'UT1': {'coords': (75, 25), 'color': 'green', 'marker': 's'},          # Using square as extended rectangle
    'UT2': {'coords': (125, 25), 'color': 'magenta', 'marker': 's'},       # Same as UT1
    'UT3': {'coords': (100, 75), 'color': 'yellow', 'marker': 's'},        # Same as UT1
    'UAV-RIS DDPG with NOMA': {'coords': (102, 50), 'color': 'black', 'marker': 'o'},    # Circle marker
    'Genetic Algorithm with NOMA': {'coords': (99, 53), 'color': 'brown', 'marker': 'o'},# Circle marker
    'DDPG without NOMA': {'coords': (94, 44), 'color': 'purple', 'marker': 'o'},         # Circle marker
    'Genetic Algorithm without NOMA': {'coords': (102, 47), 'color': 'cyan', 'marker': 'o'}  # Circle marker
}

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Adding points to the plot
for label, details in points.items():
    ax.scatter(details['coords'][0], details['coords'][1], color=details['color'],
               s=100, label=label, marker=details['marker'])

# Set plot title and labels
ax.set_title('Customized Coordinates Plot with Specific Markers and Colors')
ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')

# Show legend
ax.legend()

# Show the plot
ax.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the coordinates and labels
points = {
    'Base Station': {'coords': (45, 30), 'color': 'blue', 'marker': '^', 'label': 'BS'},  # Using a triangle marker
    'UAV-RIS': {'coords': (100, 50), 'color': 'orange', 'marker': 'v', 'label': 'UR'},   # Triangle marker, pointing down
    'Obstacle': {'coords': (80, 40), 'color': 'red', 'marker': 'X', 'label': 'O'},       # Using 'X' for danger
    'UT1': {'coords': (75, 25), 'color': 'green', 'marker': 's', 'label': 'UT1'},        # Using square as extended rectangle
    'UT2': {'coords': (125, 25), 'color': 'magenta', 'marker': 's', 'label': 'UT2'},     # Same as UT1
    'UT3': {'coords': (100, 75), 'color': 'yellow', 'marker': 's', 'label': 'UT3'},      # Same as UT1
    'UAV-RIS DDPG with NOMA': {'coords': (102, 50), 'color': 'black', 'marker': 'o', 'label': 'DDN'},    # Circle marker
    'Genetic Algorithm with NOMA': {'coords': (99, 53), 'color': 'brown', 'marker': 'o', 'label': 'GAN'},# Circle marker
    'DDPG without NOMA': {'coords': (94, 44), 'color': 'purple', 'marker': 'o', 'label': 'DDP'},         # Circle marker
    'Genetic Algorithm without NOMA': {'coords': (102, 47), 'color': 'cyan', 'marker': 'o', 'label': 'GA'}  # Circle marker
}

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Adding points to the plot
for label, details in points.items():
    ax.scatter(details['coords'][0], details['coords'][1], color=details['color'],
               s=100, label=label, marker=details['marker'])
    # Adjusting text position based on marker type
    text_offset = 0.5 if details['marker'] in ['^', 'v', 'o', 's', 'X'] else 0
    ax.text(details['coords'][0], details['coords'][1] + text_offset, details['label'],
            color='white', ha='center', va='center', fontsize=8, fontweight='bold')

# Set plot title and labels
ax.set_title('Customized Coordinates Plot with Labels Inside Markers')
ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')

# Show legend
ax.legend()

# Show the plot
ax.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the coordinates and labels
points = {
    'Base Station': {'coords': (45, 30), 'color': 'blue', 'marker': '^', 'label': 'BS'},  # Using a triangle marker
    'UAV-RIS': {'coords': (100, 50), 'color': 'orange', 'marker': 'v', 'label': 'UR'},   # Triangle marker, pointing down
    'Obstacle': {'coords': (80, 40), 'color': 'red', 'marker': 'X', 'label': 'O'},       # Using 'X' for danger
    'UT1': {'coords': (75, 25), 'color': 'green', 'marker': 's', 'label': 'UT1'},        # Using square as extended rectangle
    'UT2': {'coords': (125, 25), 'color': 'magenta', 'marker': 's', 'label': 'UT2'},     # Same as UT1
    'UT3': {'coords': (100, 75), 'color': 'yellow', 'marker': 's', 'label': 'UT3'},      # Same as UT1
    'UAV-RIS DDPG with NOMA': {'coords': (102, 50), 'color': 'black', 'marker': 'o', 'label': 'DDN'},    # Circle marker
    'Genetic Algorithm with NOMA': {'coords': (99, 53), 'color': 'brown', 'marker': 'o', 'label': 'GAN'},# Circle marker
    'DDPG without NOMA': {'coords': (94, 44), 'color': 'purple', 'marker': 'o', 'label': 'DDP'},         # Circle marker
    'Genetic Algorithm without NOMA': {'coords': (102, 47), 'color': 'cyan', 'marker': 'o', 'label': 'GA'}  # Circle marker
}

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Adding points to the plot
for label, details in points.items():
    # Plot each point
    ax.scatter(details['coords'][0], details['coords'][1], color=details['color'],
               s=100, label=label, marker=details['marker'])
    # Place label inside the marker
    ax.text(details['coords'][0], details['coords'][1], details['label'],
            color='white', ha='center', va='center', fontsize=8, fontweight='bold')
    # Place label near the marker
    ax.text(details['coords'][0], details['coords'][1] + 5, label,
            color='black', ha='center', va='bottom', fontsize=9)

# Set plot title and labels
ax.set_title('Customized Coordinates Plot with Labels Inside and Near Markers')
ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')

# Show legend
ax.legend()

# Show the plot
ax.grid(True)
plt.show()
